# %% [markdown]
# # DeePTB Tutorial 2: data preparation for deeptb-sk model  [v2.2]

# %% [markdown]
# <div style="color:black; background-color:#FFF3E9; border: 1px solid #FFE0C3; border-radius: 10px; margin-bottom:1rem">
#     <p style="margin:1rem; padding-left: 1rem; line-height: 2.5;">
#         Author: <a style="font-weight:normal" href="mailto:guqq@ustc.edu.cn">Gu, Qiangqiang 顾强强 📨 </a></b></i><br/>
#         Date: 2025-04-20<br/>
#         Protocol：<a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License.</a></i><br/>
#         Quick Start：Click the <span style="background-color:rgb(85, 91, 228); color:white; padding: 3px; border-radius: 5px;box-shadow: 2px 2px 3px rgba(0, 0, 0, 0.3); font-size:0.75rem;">Start Connection</span> button，then wait a moment to begin.
#     </p>
# </div>

# %% [markdown]
# ## Introduction
# **DeePTB** is a method that uses deep learning to accelerate first-principles electronic structure simulations.
#
# ### Version Features
# - **v1**: Constructed tight-binding (TB) models with first-principles accuracy (DeePTB-SK)
# - **v2.0-2.1**: Added E3 equivariant networks to represent single-electron operators (Hamiltonian, density matrix, and overlap matrix) (DeePTB-E3)
# - **v2.2**: Incorporated built-in SK empirical parameters covering commonly used elements across the periodic table
#
# Through these capabilities, DeePTB provides multiple approaches to accelerate electronic structure simulations of materials.
#
# ### Learning Objectives
#
# In this tutorial, you will:
# 1. Learn how to prepare data for DeePTB-SK models
# 2. Become familiar with the initial training scheme for DeePTB-SK

# %% [markdown]
# ## 1. Prepare Data for DeePTB-SK Model
# This section will show how to prepare data for DeePTB-SK model. The training label of DeePTB-SK model is the energy eigenvalue. This tutorial will show the usage of DFTIO with two DFT software, abacus and VASP.
#
# ### Pre-requisites
# 1. Install DFTIO, see https://github.com/deepmodeling/dftio.git
# 2. Run DFT Calculation:
#
#    For a given structure, perform static calculations using either ABACUS or VASP. Self-consistent or non-self-consistent calculations are both acceptable. This tutorial will use ABACUS and VASP as examples to prepare data. The following sections will describe the usage of DFTIO for both software.
#
# You can run `dftio -h` and `dftio <command> -h` to view the help documentation.

# %%
# !dftio -h
# Out:
# usage: dftio [-h] [-v] {parse,band} ...
#
# dftio is to assist machine learning communities to transcript DFT output into
# a format that is easy to read or used by machine learning models.
#
# optional arguments:
#   -h, --help     show this help message and exit
#   -v, --version  show the dftio's version number and exit
#
# Valid subcommands:
#   {parse,band}
#     parse        parse dataset from DFT output
#     band         plot band for eigenvalues data

# %%
# !dftio parse -h
# Out:
# usage: dftio parse [-h] [-ll {DEBUG,3,INFO,2,WARNING,1,ERROR,0}]
#                    [-lp LOG_PATH] [-m MODE] [-n NUM_WORKERS] [-r ROOT]
#                    [-p PREFIX] [-o OUTROOT] [-f FORMAT] [-ham] [-ovp] [-dm]
#                    [-eig] [-min BAND_INDEX_MIN]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -ll {DEBUG,3,INFO,2,WARNING,1,ERROR,0}, --log-level {DEBUG,3,INFO,2,WARNING,1,ERROR,0}
#                         set verbosity level by string or number, 0=ERROR,
#                         1=WARNING, 2=INFO and 3=DEBUG (default: INFO)
#   -lp LOG_PATH, --log-path LOG_PATH
#                         set log file to log messages to disk, if not
#                         specified, the logs will only be output to console
#                         (default: None)
#   -m MODE, --mode MODE  The name of the DFT software, currently support
#                         abacus/rescu/siesta/gaussian (default: abacus)
#   -n NUM_WORKERS, --num_workers NUM_WORKERS
#                         The number of workers used to parse the dataset. (For
#                         n>1, we use the multiprocessing to accelerate io.)
#                         (default: 1)
#   -r ROOT, --root ROOT  The root directory of the DFT files. (default: ./)
#   -p PREFIX, --prefix PREFIX
#                         The prefix of the DFT files under root. (default:
#                         frame)
#   -o OUTROOT, --outroot OUTROOT
#                         The output root directory. (default: ./)
#   -f FORMAT, --format FORMAT
#                         The output file format, should be dat, ase or lmdb.
#                         (default: dat)
#   -ham, --hamiltonian   Whether to parse the Hamiltonian matrix. (default:
#                         False)
#   -ovp, --overlap       Whether to parse the Overlap matrix (default: False)
#   -dm, --density_matrix
#                         Whether to parse the Density matrix (default: False)
#   -eig, --eigenvalue    Whether to parse the kpoints and eigenvalues (default:
#                         False)
#   -min BAND_INDEX_MIN, --band_index_min BAND_INDEX_MIN
#                         The initial band index for eigenvalues to
#                         save.(0-band_index_min) bands will be ignored!
#                         (default: 0)

# %% [markdown]
# ###  1.1 ABACUS Case:
#
# The following folder contains the result files from ABACUS calculations. We will demonstrate how to convert the ABACUS calculation data into the training data format for the DeePTB-SK model using a single command.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import os
current_dir = os.getcwd()
workdir=f'{current_dir}/data/GaAs_io_sk/data'
os.chdir(f"{workdir}")
# !tree -L 1 ./
# Out:
# ./
# ├── ABACUS
# ├── VASP
# ├── abc_ase
# └── vasp_ase
#
# 5 directories, 0 files

# %% [markdown]
# The command to process the data is as follows:

# %%
! dftio parse -m abacus -r ./ -p ABACUS -f ase -o abc_ase -eig
# Out:
# /Users/aisiqg/Software/venv/pydptb/lib/python3.9/site-packages/dpdata/system.py:1106: UserWarning: Data type spins is registered twice; only the newly registered one will be used.
#   warnings.warn(
# Parsing the DFT files: 100%|█████████████████████| 1/1 [00:00<00:00, 296.73it/s]

# %% [markdown]
# The command above, the meaning of each parameter is as follows:
# - `-m`: Specify the software, can be abacus, vasp, etc., default is abacus
# - `-r`: root_dir, the root directory of the calculation results
# - `-p`: prefix, the prefix of the calculation results, will search all file names: The retrieval rule is: `glob.glob(root + '/*' + prefix + '*')`
# - `-f`: format output data format: dat ase lmdb; For eigenvalue training data, dat ase is a common format. lmdb is mainly for training quantum operator matrices.
# - `-o`: out_dir output folder, root_dir/out_dir
# - `-eig`: Whether to output eigenvalues, add -eig to set it to True
#
# The following command provides a preview of the corresponding eigenvalue band structure, which is convenient for analysis:

# %%
# !dftio band -r ./abc_ase/AsGa.0 -f ase 

# display the band plot:
image_path = f'{workdir}/abc_ase/AsGa.0/band_structure.png'
img = mpimg.imread(image_path)
plt.figure(figsize=(10, 8))
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# Figure(640x480)

# %% [markdown]
# The plotting command:
# ```python
# dftio band -r ./abc_ase/AsGa.0 -f ase
# ```
# The meaning of the parameters is as follows:
# - `-r` : root_dir, the root directory of the calculation results. Batch plotting is not supported here, so we directly specify the folder containing the parsed data from the previous step without using the prefix and search folder mode.
# - `-f` : format, corresponding to the output format during parsing, ase or dat

# %% [markdown]
# ### Band structure analysis
#
# For the above band structure, we can see that some bands belong to core orbitals. We do not need these bands for training the TB model. We can remove these bands by adding an extra parameter to the above command.
#
# We first check how many bands we want to remove. We can visualize the band structure to see this:

# %%
# !dftio band -r ./abc_ase/AsGa.0 -f ase -min 5

# display the band plot:

image_path = f'{workdir}/abc_ase/AsGa.0/band_structure.png'
img = mpimg.imread(image_path)
plt.figure(figsize=(10, 8))
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# Figure(640x480)

# %% [markdown]
# Note that the above plotting command has an extra parameter:
# - `-min` specifies the starting band for plotting.
#
# For example, `-min 5` means starting from the 5th band, as the counting starts from 0. This indicates that the first 5 bands are completely discarded.
#
# Users can change the value of `-min` to check the band structure. After determining the appropriate value for `-min`, we can rerun the `dftio parse` command with this parameter.
#
# Additionally, users should ensure that the chosen `-min` value does not exceed the total number of bands available in the dataset.

# %%
# !dftio parse -m abacus -r ./ -p ABACUS -f ase -o abc_ase -eig -min 5
# Out:
# /Users/aisiqg/Software/venv/pydptb/lib/python3.9/site-packages/dpdata/system.py:1106: UserWarning: Data type spins is registered twice; only the newly registered one will be used.
#   warnings.warn(
# Parsing the DFT files: 100%|█████████████████████| 1/1 [00:00<00:00, 306.94it/s]

# %% [markdown]
# The above command will remove the first 5 bands from the band structure plot.

# %%
# !dftio band -r ./abc_ase/AsGa.0 -f ase # -min 0

# display the band plot:
image_path = f'{workdir}/abc_ase/AsGa.0/band_structure.png'

img = mpimg.imread(image_path)
plt.figure(figsize=(10, 8))
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# Figure(640x480)

# %% [markdown]
# ### Finally, the training data set format for DeePTB-SK model is obtained.

# %%
# !tree -L 2 ./abc_ase
# Out:
# ./abc_ase
# └── AsGa.0
#     ├── band_structure.png
#     ├── eigenvalues.npy
#     ├── kpoints.npy
#     └── xdat.traj
#
# 2 directories, 4 files

# %% [markdown]
# ###  1.2. VASP Case:
#
# The following folder contains the result files from VASP calculations.

# %%
workdir=f'{current_dir}/data/GaAs_io_sk/data/'
os.chdir(f"{workdir}")
! tree ./VASP -L 1
# Out:
# ./VASP
# ├── EIGENVAL
# ├── KPOINTS
# ├── OUTCAR
# └── POSCAR
#
# 1 directory, 4 files

# %% [markdown]
# using the same command as in the ABACUS case, but with the `-m` parameter set to `vasp`:

# %%
! dftio parse -m vasp -r ./ -p VASP -f ase -o vasp_ase -eig
# Out:
# DFTIO WARNING VASP parser only supports the static (SCF or NSCF) calculations. MD and RELAX is not supported yet.
# DFTIO WARNING VASP parser only supports the static (SCF or NSCF) calculations. MD and RELAX is not supported yet.
# Parsing the DFT files: 100%|█████████████████████| 1/1 [00:00<00:00, 156.74it/s]

# %% [markdown]
# Observe that the above command is the same as the abacus case, except for the `-m` parameter, which is set to `vasp`.
#
# For visualizing the band structure of data already output in ASE format, the process is similar to that of the ABACUS case.

# %%
# !dftio band -r ./vasp_ase/AsGa.0 -f ase 

# display the band plot:
image_path = f'{workdir}/vasp_ase/AsGa.0/band_structure.png'
img = mpimg.imread(image_path)
plt.figure(figsize=(10, 8))
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# Figure(640x480)

# %% [markdown]
# Again, there are core orbitals in the band structure. We can use the same method as in the ABACUS case to remove these bands.

# %% [markdown]
# Again, by visualization, we can get the information about how many bands need to be removed:

# %%
# !dftio band -r ./vasp_ase/AsGa.0 -f ase  -min 5

# display the band plot:
image_path = f'{workdir}/vasp_ase/AsGa.0/band_structure.png'

img = mpimg.imread(image_path)
plt.figure(figsize=(10, 8))
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# Figure(640x480)

# %% [markdown]
# Re-run the data processing command to discard the lower energy bands. The command is as follows:

# %%
! dftio parse -m vasp -r ./ -p VASP -f ase -o vasp_ase -eig -min 5
# Out:
# DFTIO WARNING VASP parser only supports the static (SCF or NSCF) calculations. MD and RELAX is not supported yet.
# DFTIO WARNING VASP parser only supports the static (SCF or NSCF) calculations. MD and RELAX is not supported yet.
# Parsing the DFT files: 100%|█████████████████████| 1/1 [00:00<00:00, 150.35it/s]

# %% [markdown]
# To confirm the band structure, we can visualize it again. The command is as follows:

# %%
# !dftio band -r ./vasp_ase/AsGa.0 -f ase # -min 5

# display the band plot:
image_path = f'{workdir}/vasp_ase/AsGa.0/band_structure.png'
img = mpimg.imread(image_path)
plt.figure(figsize=(10, 8))
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# Figure(640x480)

# %% [markdown]
# ### Finally, the training data set format for DeePTB-SK model is obtained.

# %% [markdown]
# **Note:**
#
# After the above operations, the obtained data only contains one frame structure. If you have multiple frame structures, you can perform the following two operations:
#
# 1. Place different structures in different folders, using the same prefix and different suffixes for naming. Different folders should be placed in the same directory. The data structure is as follows:
#     ```bash
#       .root_dir
#       └── prefix.suffix1
#           ├── info.json
#           ├── eigenvalues.npy
#           ├── kpoints.npy
#           └── xdat.traj
#       └── prefix.suffix2
#           ├── info.json
#           ├── eigenvalues.npy
#           ├── kpoints.npy
#           └── xdat.traj
#       └── ...
#     ```
#
#     **Note**: You may notice that I added an `info.json` file! This file contains some parameter settings for the training set, which are required when training DeePTB-SK. Please refer to the DeePTB-SK tutorial for details.
#
# 2. In another case, if the data for different frames of structures is the same except for the atomic coordinates (e.g., different structures in the same MD trajectory), you can merge them into one file. The `xdat.traj` file is used to save different frames of structures, and the shape of `eigenvalues.npy` is [nframe,nk,nb]. The shape of `kpoints` can be [nframe,nk,nb] or [nk,nb], where the latter indicates that this structure uses the same kpoints.

# %% [markdown]
# ## 2. **Training DeePTB-SK Model using vasp data**

# %% [markdown]
# In the previous step, we have prepared the data, and now we can start training the model.

# %%
import os
workdir=f'{current_dir}/data/GaAs_io_sk/'
os.chdir(f"{workdir}")
# !tree -L 1 ./data/vasp_ase
# Out:
# ./data/vasp_ase
# ├── AsGa.0
# └── processed_dataset_22915fbb7a750e40346716ff89f45ffe8cc73ea3
#
# 3 directories, 0 files

# %% [markdown]
# First, we need to create an `info.json` file in the data folder with the following content:
# ```json
# {
#     "nframes": 1,
#     "natoms": 2,
#     "pos_type": "ase",
#     "pbc": true,
#     "bandinfo": {
#         "band_min": 0,
#         "band_max": 8,
#         "emin": null,
#         "emax": null
#     }
# }
# ```
# `nframes` indicates the number of trajectory snapshots, `natoms` indicates the number of atoms in each snapshot, `pos_type` indicates the coordinate type, and `pbc` indicates whether periodic boundary conditions are applied. The `bandinfo` section contains information about the band window, which can be set according to the user's needs. The band window information can be sorted by band index or divided by energy range. Note that the value of emin is relative to min(eig[band_min]). Taking min(eig[band_min]) as the 0 energy.

# %%
import json 

infodict = {
    "nframes": 1,
    "natoms": 2,
    "pos_type": "ase",
    "pbc": True,
    "bandinfo": {
        "band_min": 0,
        "band_max": 8,
        "emin": None,
        "emax": None
        }
    }

with open(f'{workdir}/data/vasp_ase/AsGa.0/info.json', 'w') as f:
    json.dump(infodict, f, indent=4)

# %% [markdown]
# ### 2.1 Extract initial empirical SK parameters

# %% [markdown]
# Refer to tutorial 1, we extract the initial SK parameters of GaAs from the built-in baseline model.

# %%
os.chdir(f"{workdir}/train")
# !dptb esk gaas.json -m poly4
# Out:
# TBPLaS is not installed. Thus the TBPLaS is not available, Please install it first.
#
#
# #################################################################################
# #                                                                               #
# #                                                                               #
# #      ██████████                     ███████████  ███████████ ███████████      #
# #     ░░███░░░░███                   ░░███░░░░░███░█░░░███░░░█░░███░░░░░███     #
# #      ░███   ░░███  ██████   ██████  ░███    ░███░   ░███  ░  ░███    ░███     #
# #      ░███    ░███ ███░░███ ███░░███ ░██████████     ░███     ░██████████      #
# #      ░███    ░███░███████ ░███████  ░███░░░░░░      ░███     ░███░░░░░███     #
# #      ░███    ███ ░███░░░  ░███░░░   ░███            ░███     ░███    ░███     #
# #      ██████████  ░░██████ ░░██████  █████           █████    ███████████      #
# #     ░░░░░░░░░░    ░░░░░░   ░░░░░░  ░░░░░           ░░░░░    ░░░░░░░░░░░       #
# #                                                                               #
# #                         Version: 2.2.1.dev20+bcb3cf2                          #
# #                                                                               #
# #################################################################################
#
#
# DEEPTB INFO    Extracting empirical SK parameters for GaAs
# DEEPTB INFO    dtype is not provided in the input json, set to the value torch.float32 in model ckpt.
# DEEPTB INFO    device is not provided in the input json, set to the value cpu in model ckpt.
# DEEPTB INFO    overlap is not provided in the input json, set to the value True in model ckpt.
# DEEPTB INFO    Empirical SK parameters are saved in ./sktb.json
# DEEPTB INFO    If you want to further train the model, please use `dptb config` command to generate input template.

# %% [markdown]
# We can compare the initial model band structure with the DFT band structure to see how well the model fits the DFT results.

# %%
# !dptb run band.json -i sktb.json -o  band 

# display the band plot:
image_path = f'./band/results/band.png'
img = mpimg.imread(image_path)
plt.figure(figsize=(10, 8))
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# TBPLaS is not installed. Thus the TBPLaS is not available, Please install it first.
#
#
# #################################################################################
# #                                                                               #
# #                                                                               #
# #      ██████████                     ███████████  ███████████ ███████████      #
# #     ░░███░░░░███                   ░░███░░░░░███░█░░░███░░░█░░███░░░░░███     #
# #      ░███   ░░███  ██████   ██████  ░███    ░███░   ░███  ░  ░███    ░███     #
# #      ░███    ░███ ███░░███ ███░░███ ░██████████     ░███     ░██████████      #
# #      ░███    ░███░███████ ░███████  ░███░░░░░░      ░███     ░███░░░░░███     #
# #      ░███    ███ ░███░░░  ░███░░░   ░███            ░███     ░███    ░███     #
# #      ██████████  ░░██████ ░░██████  █████           █████    ███████████      #
# #     ░░░░░░░░░░    ░░░░░░   ░░░░░░  ░░░░░           ░░░░░    ░░░░░░░░░░░       #
# #                                                                               #
# #                         Version: 2.2.1.dev20+bcb3cf2                          #
# #                                                                               #
# #################################################################################
#
#
# DEEPTB WARNING CUDA is not available. The model will be loaded on CPU.
# DEEPTB WARNING Warning! structure is not set in run option, read from input config file.
# /Users/aisiqg/Software/venv/pydptb/lib/python3.9/site-packages/torch/nested/__init__.py:58: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/NestedTensorImpl.cpp:180.)
#   return torch._nested_tensor_from_tensor_list(tensor_list, dtype, None, device, None)
# DEEPTB INFO    KPOINTS  klist: 180 kpoints
# DEEPTB INFO    The eigenvalues are already in data. will use them.
# DEEPTB INFO    Calculating Fermi energy in the case of spin-degeneracy.
# DEEPTB INFO    Fermi energy converged after 16 iterations.
# DEEPTB INFO    q_cal: 7.999999999918035, total_electrons: 8.0, diff q: 8.196465728360636e-11
# DEEPTB INFO    Estimated E_fermi: -4.9278943551580685 based on the valence electrons setting nel_atom : {'As': 5, 'Ga': 3} .
# DEEPTB INFO    No Fermi energy provided, using estimated value: -4.9279 eV
# Figure(640x560)
# DEEPTB INFO    band calculation successfully completed.

# %% [markdown]
# ### 2.1 model training (briefly introduce)

# %%
# 94.116 s on NVIDIA V100
# !dptb train input.json -i sktb.json -o nnsk
# Out:
# TBPLaS is not installed. Thus the TBPLaS is not available, Please install it first.
#
#
# #################################################################################
# #                                                                               #
# #                                                                               #
# #      ██████████                     ███████████  ███████████ ███████████      #
# #     ░░███░░░░███                   ░░███░░░░░███░█░░░███░░░█░░███░░░░░███     #
# #      ░███   ░░███  ██████   ██████  ░███    ░███░   ░███  ░  ░███    ░███     #
# #      ░███    ░███ ███░░███ ███░░███ ░██████████     ░███     ░██████████      #
# #      ░███    ░███░███████ ░███████  ░███░░░░░░      ░███     ░███░░░░░███     #
# #      ░███    ███ ░███░░░  ░███░░░   ░███            ░███     ░███    ░███     #
# #      ██████████  ░░██████ ░░██████  █████           █████    ███████████      #
# #     ░░░░░░░░░░    ░░░░░░   ░░░░░░  ░░░░░           ░░░░░    ░░░░░░░░░░░       #
# #                                                                               #
# #                         Version: 2.2.1.dev12+5b97981                          #
# #                                                                               #
# #################################################################################
#
#
# DEEPTB INFO    ------------------------------------------------------------------
# DEEPTB INFO         Cutoff options:
# DEEPTB INFO
# DEEPTB INFO         r_max            : {'Ga-Ga': 6.220000000000001, 'Ga-As': 6.43, 'As-Ga': 6.43, 'As-As': 6.630000000000001}
# DEEPTB INFO         er_max           : None
# DEEPTB INFO         oer_max          : None
# DEEPTB INFO    ------------------------------------------------------------------
# /Users/aisiqg/Software/venv/pydptb/lib/python3.9/site-packages/torch/nested/__init__.py:58: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/NestedTensorImpl.cpp:180.)
#   return torch._nested_tensor_from_tensor_list(tensor_list, dtype, None, device, None)
# DEEPTB WARNING The cutoffs in data and model are not checked. be careful!
# DEEPTB INFO    The ['overlap_param'] are frozen!
# DEEPTB INFO    The ['overlap_param'] are frozen!
# DEEPTB INFO    The ['overlap_param'] are frozen!
# DEEPTB INFO    Model parameters: 246,  |    (About 0.25K)  |    (About 0.000M)  |    (About 0.0000B)
# DEEPTB INFO    iteration:1	train_loss: 4.5888  (1.3766)	lr: 0.01
# DEEPTB INFO    checkpoint saved as nnsk.iter1
# DEEPTB INFO    Epoch 1 summary:	train_loss: 4.5888
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep1
# DEEPTB INFO    iteration:2	train_loss: 3.2264  (1.9316)	lr: 0.00997
# DEEPTB INFO    checkpoint saved as nnsk.iter2
# DEEPTB INFO    Epoch 2 summary:	train_loss: 3.2264
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep2
# DEEPTB INFO    iteration:3	train_loss: 2.2542  (2.0283)	lr: 0.00994
# DEEPTB INFO    checkpoint saved as nnsk.iter3
# DEEPTB INFO    Epoch 3 summary:	train_loss: 2.2542
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep3
# DEEPTB INFO    iteration:4	train_loss: 1.6229  (1.9067)	lr: 0.00991
# DEEPTB INFO    checkpoint saved as nnsk.iter4
# DEEPTB INFO    Epoch 4 summary:	train_loss: 1.6229
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep4
# DEEPTB INFO    iteration:5	train_loss: 1.2824  (1.7194)	lr: 0.009881
# DEEPTB INFO    checkpoint saved as nnsk.iter5
# DEEPTB INFO    Epoch 5 summary:	train_loss: 1.2824
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep5
# DEEPTB INFO    iteration:6	train_loss: 1.1724  (1.5553)	lr: 0.009851
# DEEPTB INFO    checkpoint saved as nnsk.iter6
# DEEPTB INFO    Epoch 6 summary:	train_loss: 1.1724
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep6
# DEEPTB INFO    iteration:7	train_loss: 1.2056  (1.4504)	lr: 0.009821
# DEEPTB INFO    checkpoint saved as nnsk.iter7
# DEEPTB INFO    Epoch 7 summary:	train_loss: 1.2056
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:8	train_loss: 1.2805  (1.3994)	lr: 0.009792
# DEEPTB INFO    checkpoint saved as nnsk.iter8
# DEEPTB INFO    Epoch 8 summary:	train_loss: 1.2805
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:9	train_loss: 1.3146  (1.3740)	lr: 0.009763
# DEEPTB INFO    checkpoint saved as nnsk.iter9
# DEEPTB INFO    Epoch 9 summary:	train_loss: 1.3146
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:10	train_loss: 1.2717  (1.3433)	lr: 0.009733
# DEEPTB INFO    checkpoint saved as nnsk.iter10
# DEEPTB INFO    Epoch 10 summary:	train_loss: 1.2717
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:11	train_loss: 1.1576  (1.2876)	lr: 0.009704
# DEEPTB INFO    checkpoint saved as nnsk.iter11
# DEEPTB INFO    Epoch 11 summary:	train_loss: 1.1576
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep11
# DEEPTB INFO    iteration:12	train_loss: 1.0031  (1.2022)	lr: 0.009675
# DEEPTB INFO    checkpoint saved as nnsk.iter12
# DEEPTB INFO    Epoch 12 summary:	train_loss: 1.0031
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep12
# DEEPTB INFO    iteration:13	train_loss: 0.8408  (1.0938)	lr: 0.009646
# DEEPTB INFO    checkpoint saved as nnsk.iter13
# DEEPTB INFO    Epoch 13 summary:	train_loss: 0.8408
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep13
# DEEPTB INFO    iteration:14	train_loss: 0.7022  (0.9763)	lr: 0.009617
# DEEPTB INFO    checkpoint saved as nnsk.iter14
# DEEPTB INFO    Epoch 14 summary:	train_loss: 0.7022
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep14
# DEEPTB INFO    iteration:15	train_loss: 0.6047  (0.8649)	lr: 0.009588
# DEEPTB INFO    checkpoint saved as nnsk.iter15
# DEEPTB INFO    Epoch 15 summary:	train_loss: 0.6047
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep15
# DEEPTB INFO    iteration:16	train_loss: 0.5491  (0.7701)	lr: 0.009559
# DEEPTB INFO    checkpoint saved as nnsk.iter16
# DEEPTB INFO    Epoch 16 summary:	train_loss: 0.5491
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep16
# DEEPTB INFO    iteration:17	train_loss: 0.5269  (0.6972)	lr: 0.009531
# DEEPTB INFO    checkpoint saved as nnsk.iter17
# DEEPTB INFO    Epoch 17 summary:	train_loss: 0.5269
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep17
# DEEPTB INFO    iteration:18	train_loss: 0.5214  (0.6444)	lr: 0.009502
# DEEPTB INFO    checkpoint saved as nnsk.iter18
# DEEPTB INFO    Epoch 18 summary:	train_loss: 0.5214
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep18
# DEEPTB INFO    iteration:19	train_loss: 0.5092  (0.6039)	lr: 0.009474
# DEEPTB INFO    checkpoint saved as nnsk.iter19
# DEEPTB INFO    Epoch 19 summary:	train_loss: 0.5092
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep19
# DEEPTB INFO    iteration:20	train_loss: 0.4830  (0.5676)	lr: 0.009445
# DEEPTB INFO    checkpoint saved as nnsk.iter20
# DEEPTB INFO    Epoch 20 summary:	train_loss: 0.4830
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep20
# DEEPTB INFO    iteration:21	train_loss: 0.4451  (0.5309)	lr: 0.009417
# DEEPTB INFO    checkpoint saved as nnsk.iter21
# DEEPTB INFO    Epoch 21 summary:	train_loss: 0.4451
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep21
# DEEPTB INFO    iteration:22	train_loss: 0.4086  (0.4942)	lr: 0.009389
# DEEPTB INFO    checkpoint saved as nnsk.iter22
# DEEPTB INFO    Epoch 22 summary:	train_loss: 0.4086
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep22
# DEEPTB INFO    iteration:23	train_loss: 0.3916  (0.4634)	lr: 0.00936
# DEEPTB INFO    checkpoint saved as nnsk.iter23
# DEEPTB INFO    Epoch 23 summary:	train_loss: 0.3916
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep23
# DEEPTB INFO    iteration:24	train_loss: 0.3963  (0.4433)	lr: 0.009332
# DEEPTB INFO    checkpoint saved as nnsk.iter24
# DEEPTB INFO    Epoch 24 summary:	train_loss: 0.3963
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:25	train_loss: 0.3878  (0.4266)	lr: 0.009304
# DEEPTB INFO    checkpoint saved as nnsk.iter25
# DEEPTB INFO    Epoch 25 summary:	train_loss: 0.3878
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep25
# DEEPTB INFO    iteration:26	train_loss: 0.3593  (0.4064)	lr: 0.009276
# DEEPTB INFO    checkpoint saved as nnsk.iter26
# DEEPTB INFO    Epoch 26 summary:	train_loss: 0.3593
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep26
# DEEPTB INFO    iteration:27	train_loss: 0.3302  (0.3836)	lr: 0.009249
# DEEPTB INFO    checkpoint saved as nnsk.iter27
# DEEPTB INFO    Epoch 27 summary:	train_loss: 0.3302
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep27
# DEEPTB INFO    iteration:28	train_loss: 0.3148  (0.3630)	lr: 0.009221
# DEEPTB INFO    checkpoint saved as nnsk.iter28
# DEEPTB INFO    Epoch 28 summary:	train_loss: 0.3148
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep28
# DEEPTB INFO    iteration:29	train_loss: 0.3125  (0.3478)	lr: 0.009193
# DEEPTB INFO    checkpoint saved as nnsk.iter29
# DEEPTB INFO    Epoch 29 summary:	train_loss: 0.3125
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep29
# DEEPTB INFO    iteration:30	train_loss: 0.3122  (0.3371)	lr: 0.009166
# DEEPTB INFO    checkpoint saved as nnsk.iter30
# DEEPTB INFO    Epoch 30 summary:	train_loss: 0.3122
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep30
# DEEPTB INFO    iteration:31	train_loss: 0.3051  (0.3275)	lr: 0.009138
# DEEPTB INFO    checkpoint saved as nnsk.iter31
# DEEPTB INFO    Epoch 31 summary:	train_loss: 0.3051
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep31
# DEEPTB INFO    iteration:32	train_loss: 0.2914  (0.3167)	lr: 0.009111
# DEEPTB INFO    checkpoint saved as nnsk.iter32
# DEEPTB INFO    Epoch 32 summary:	train_loss: 0.2914
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep32
# DEEPTB INFO    iteration:33	train_loss: 0.2777  (0.3050)	lr: 0.009083
# DEEPTB INFO    checkpoint saved as nnsk.iter33
# DEEPTB INFO    Epoch 33 summary:	train_loss: 0.2777
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep33
# DEEPTB INFO    iteration:34	train_loss: 0.2702  (0.2946)	lr: 0.009056
# DEEPTB INFO    checkpoint saved as nnsk.iter34
# DEEPTB INFO    Epoch 34 summary:	train_loss: 0.2702
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep34
# DEEPTB INFO    iteration:35	train_loss: 0.2699  (0.2872)	lr: 0.009029
# DEEPTB INFO    checkpoint saved as nnsk.iter35
# DEEPTB INFO    Epoch 35 summary:	train_loss: 0.2699
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep35
# DEEPTB INFO    iteration:36	train_loss: 0.2698  (0.2820)	lr: 0.009002
# DEEPTB INFO    checkpoint saved as nnsk.iter36
# DEEPTB INFO    Epoch 36 summary:	train_loss: 0.2698
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep36
# DEEPTB INFO    iteration:37	train_loss: 0.2634  (0.2764)	lr: 0.008975
# DEEPTB INFO    checkpoint saved as nnsk.iter37
# DEEPTB INFO    Epoch 37 summary:	train_loss: 0.2634
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep37
# DEEPTB INFO    iteration:38	train_loss: 0.2526  (0.2693)	lr: 0.008948
# DEEPTB INFO    checkpoint saved as nnsk.iter38
# DEEPTB INFO    Epoch 38 summary:	train_loss: 0.2526
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep38
# DEEPTB INFO    iteration:39	train_loss: 0.2436  (0.2616)	lr: 0.008921
# DEEPTB INFO    checkpoint saved as nnsk.iter39
# DEEPTB INFO    Epoch 39 summary:	train_loss: 0.2436
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep39
# DEEPTB INFO    iteration:40	train_loss: 0.2385  (0.2546)	lr: 0.008894
# DEEPTB INFO    checkpoint saved as nnsk.iter40
# DEEPTB INFO    Epoch 40 summary:	train_loss: 0.2385
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep40
# DEEPTB INFO    iteration:41	train_loss: 0.2348  (0.2487)	lr: 0.008868
# DEEPTB INFO    checkpoint saved as nnsk.iter41
# DEEPTB INFO    Epoch 41 summary:	train_loss: 0.2348
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep41
# DEEPTB INFO    iteration:42	train_loss: 0.2299  (0.2431)	lr: 0.008841
# DEEPTB INFO    checkpoint saved as nnsk.iter42
# DEEPTB INFO    Epoch 42 summary:	train_loss: 0.2299
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep42
# DEEPTB INFO    iteration:43	train_loss: 0.2228  (0.2370)	lr: 0.008814
# DEEPTB INFO    checkpoint saved as nnsk.iter43
# DEEPTB INFO    Epoch 43 summary:	train_loss: 0.2228
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep43
# DEEPTB INFO    iteration:44	train_loss: 0.2148  (0.2303)	lr: 0.008788
# DEEPTB INFO    checkpoint saved as nnsk.iter44
# DEEPTB INFO    Epoch 44 summary:	train_loss: 0.2148
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep44
# DEEPTB INFO    iteration:45	train_loss: 0.2081  (0.2237)	lr: 0.008762
# DEEPTB INFO    checkpoint saved as nnsk.iter45
# DEEPTB INFO    Epoch 45 summary:	train_loss: 0.2081
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep45
# DEEPTB INFO    iteration:46	train_loss: 0.2035  (0.2176)	lr: 0.008735
# DEEPTB INFO    checkpoint saved as nnsk.iter46
# DEEPTB INFO    Epoch 46 summary:	train_loss: 0.2035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep46
# DEEPTB INFO    iteration:47	train_loss: 0.1997  (0.2122)	lr: 0.008709
# DEEPTB INFO    checkpoint saved as nnsk.iter47
# DEEPTB INFO    Epoch 47 summary:	train_loss: 0.1997
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep47
# DEEPTB INFO    iteration:48	train_loss: 0.1950  (0.2071)	lr: 0.008683
# DEEPTB INFO    checkpoint saved as nnsk.iter48
# DEEPTB INFO    Epoch 48 summary:	train_loss: 0.1950
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep48
# DEEPTB INFO    iteration:49	train_loss: 0.1889  (0.2016)	lr: 0.008657
# DEEPTB INFO    checkpoint saved as nnsk.iter49
# DEEPTB INFO    Epoch 49 summary:	train_loss: 0.1889
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep49
# DEEPTB INFO    iteration:50	train_loss: 0.1825  (0.1959)	lr: 0.008631
# DEEPTB INFO    checkpoint saved as nnsk.iter50
# DEEPTB INFO    Epoch 50 summary:	train_loss: 0.1825
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep50
# DEEPTB INFO    iteration:51	train_loss: 0.1769  (0.1902)	lr: 0.008605
# DEEPTB INFO    checkpoint saved as nnsk.iter51
# DEEPTB INFO    Epoch 51 summary:	train_loss: 0.1769
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep51
# DEEPTB INFO    iteration:52	train_loss: 0.1721  (0.1847)	lr: 0.008579
# DEEPTB INFO    checkpoint saved as nnsk.iter52
# DEEPTB INFO    Epoch 52 summary:	train_loss: 0.1721
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep52
# DEEPTB INFO    iteration:53	train_loss: 0.1673  (0.1795)	lr: 0.008554
# DEEPTB INFO    checkpoint saved as nnsk.iter53
# DEEPTB INFO    Epoch 53 summary:	train_loss: 0.1673
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep53
# DEEPTB INFO    iteration:54	train_loss: 0.1618  (0.1742)	lr: 0.008528
# DEEPTB INFO    checkpoint saved as nnsk.iter54
# DEEPTB INFO    Epoch 54 summary:	train_loss: 0.1618
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep54
# DEEPTB INFO    iteration:55	train_loss: 0.1556  (0.1686)	lr: 0.008502
# DEEPTB INFO    checkpoint saved as nnsk.iter55
# DEEPTB INFO    Epoch 55 summary:	train_loss: 0.1556
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep55
# DEEPTB INFO    iteration:56	train_loss: 0.1496  (0.1629)	lr: 0.008477
# DEEPTB INFO    checkpoint saved as nnsk.iter56
# DEEPTB INFO    Epoch 56 summary:	train_loss: 0.1496
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep56
# DEEPTB INFO    iteration:57	train_loss: 0.1443  (0.1573)	lr: 0.008451
# DEEPTB INFO    checkpoint saved as nnsk.iter57
# DEEPTB INFO    Epoch 57 summary:	train_loss: 0.1443
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep57
# DEEPTB INFO    iteration:58	train_loss: 0.1396  (0.1520)	lr: 0.008426
# DEEPTB INFO    checkpoint saved as nnsk.iter58
# DEEPTB INFO    Epoch 58 summary:	train_loss: 0.1396
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep58
# DEEPTB INFO    iteration:59	train_loss: 0.1350  (0.1469)	lr: 0.008401
# DEEPTB INFO    checkpoint saved as nnsk.iter59
# DEEPTB INFO    Epoch 59 summary:	train_loss: 0.1350
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep59
# DEEPTB INFO    iteration:60	train_loss: 0.1303  (0.1419)	lr: 0.008376
# DEEPTB INFO    checkpoint saved as nnsk.iter60
# DEEPTB INFO    Epoch 60 summary:	train_loss: 0.1303
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep60
# DEEPTB INFO    iteration:61	train_loss: 0.1254  (0.1370)	lr: 0.00835
# DEEPTB INFO    checkpoint saved as nnsk.iter61
# DEEPTB INFO    Epoch 61 summary:	train_loss: 0.1254
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep61
# DEEPTB INFO    iteration:62	train_loss: 0.1209  (0.1321)	lr: 0.008325
# DEEPTB INFO    checkpoint saved as nnsk.iter62
# DEEPTB INFO    Epoch 62 summary:	train_loss: 0.1209
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep62
# DEEPTB INFO    iteration:63	train_loss: 0.1169  (0.1276)	lr: 0.0083
# DEEPTB INFO    checkpoint saved as nnsk.iter63
# DEEPTB INFO    Epoch 63 summary:	train_loss: 0.1169
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep63
# DEEPTB INFO    iteration:64	train_loss: 0.1135  (0.1233)	lr: 0.008276
# DEEPTB INFO    checkpoint saved as nnsk.iter64
# DEEPTB INFO    Epoch 64 summary:	train_loss: 0.1135
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep64
# DEEPTB INFO    iteration:65	train_loss: 0.1104  (0.1194)	lr: 0.008251
# DEEPTB INFO    checkpoint saved as nnsk.iter65
# DEEPTB INFO    Epoch 65 summary:	train_loss: 0.1104
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep65
# DEEPTB INFO    iteration:66	train_loss: 0.1073  (0.1158)	lr: 0.008226
# DEEPTB INFO    checkpoint saved as nnsk.iter66
# DEEPTB INFO    Epoch 66 summary:	train_loss: 0.1073
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep66
# DEEPTB INFO    iteration:67	train_loss: 0.1044  (0.1124)	lr: 0.008201
# DEEPTB INFO    checkpoint saved as nnsk.iter67
# DEEPTB INFO    Epoch 67 summary:	train_loss: 0.1044
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep67
# DEEPTB INFO    iteration:68	train_loss: 0.1016  (0.1092)	lr: 0.008177
# DEEPTB INFO    checkpoint saved as nnsk.iter68
# DEEPTB INFO    Epoch 68 summary:	train_loss: 0.1016
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep68
# DEEPTB INFO    iteration:69	train_loss: 0.0992  (0.1062)	lr: 0.008152
# DEEPTB INFO    checkpoint saved as nnsk.iter69
# DEEPTB INFO    Epoch 69 summary:	train_loss: 0.0992
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep69
# DEEPTB INFO    iteration:70	train_loss: 0.0970  (0.1034)	lr: 0.008128
# DEEPTB INFO    checkpoint saved as nnsk.iter70
# DEEPTB INFO    Epoch 70 summary:	train_loss: 0.0970
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep70
# DEEPTB INFO    iteration:71	train_loss: 0.0949  (0.1009)	lr: 0.008103
# DEEPTB INFO    checkpoint saved as nnsk.iter71
# DEEPTB INFO    Epoch 71 summary:	train_loss: 0.0949
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep71
# DEEPTB INFO    iteration:72	train_loss: 0.0927  (0.0984)	lr: 0.008079
# DEEPTB INFO    checkpoint saved as nnsk.iter72
# DEEPTB INFO    Epoch 72 summary:	train_loss: 0.0927
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep72
# DEEPTB INFO    iteration:73	train_loss: 0.0906  (0.0961)	lr: 0.008055
# DEEPTB INFO    checkpoint saved as nnsk.iter73
# DEEPTB INFO    Epoch 73 summary:	train_loss: 0.0906
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep73
# DEEPTB INFO    iteration:74	train_loss: 0.0886  (0.0938)	lr: 0.008031
# DEEPTB INFO    checkpoint saved as nnsk.iter74
# DEEPTB INFO    Epoch 74 summary:	train_loss: 0.0886
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep74
# DEEPTB INFO    iteration:75	train_loss: 0.0867  (0.0917)	lr: 0.008006
# DEEPTB INFO    checkpoint saved as nnsk.iter75
# DEEPTB INFO    Epoch 75 summary:	train_loss: 0.0867
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep75
# DEEPTB INFO    iteration:76	train_loss: 0.0849  (0.0897)	lr: 0.007982
# DEEPTB INFO    checkpoint saved as nnsk.iter76
# DEEPTB INFO    Epoch 76 summary:	train_loss: 0.0849
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep76
# DEEPTB INFO    iteration:77	train_loss: 0.0832  (0.0877)	lr: 0.007959
# DEEPTB INFO    checkpoint saved as nnsk.iter77
# DEEPTB INFO    Epoch 77 summary:	train_loss: 0.0832
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep77
# DEEPTB INFO    iteration:78	train_loss: 0.0815  (0.0859)	lr: 0.007935
# DEEPTB INFO    checkpoint saved as nnsk.iter78
# DEEPTB INFO    Epoch 78 summary:	train_loss: 0.0815
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep78
# DEEPTB INFO    iteration:79	train_loss: 0.0798  (0.0840)	lr: 0.007911
# DEEPTB INFO    checkpoint saved as nnsk.iter79
# DEEPTB INFO    Epoch 79 summary:	train_loss: 0.0798
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep79
# DEEPTB INFO    iteration:80	train_loss: 0.0782  (0.0823)	lr: 0.007887
# DEEPTB INFO    checkpoint saved as nnsk.iter80
# DEEPTB INFO    Epoch 80 summary:	train_loss: 0.0782
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep80
# DEEPTB INFO    iteration:81	train_loss: 0.0767  (0.0806)	lr: 0.007863
# DEEPTB INFO    checkpoint saved as nnsk.iter81
# DEEPTB INFO    Epoch 81 summary:	train_loss: 0.0767
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep81
# DEEPTB INFO    iteration:82	train_loss: 0.0753  (0.0790)	lr: 0.00784
# DEEPTB INFO    checkpoint saved as nnsk.iter82
# DEEPTB INFO    Epoch 82 summary:	train_loss: 0.0753
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep82
# DEEPTB INFO    iteration:83	train_loss: 0.0739  (0.0775)	lr: 0.007816
# DEEPTB INFO    checkpoint saved as nnsk.iter83
# DEEPTB INFO    Epoch 83 summary:	train_loss: 0.0739
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep83
# DEEPTB INFO    iteration:84	train_loss: 0.0725  (0.0760)	lr: 0.007793
# DEEPTB INFO    checkpoint saved as nnsk.iter84
# DEEPTB INFO    Epoch 84 summary:	train_loss: 0.0725
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep84
# DEEPTB INFO    iteration:85	train_loss: 0.0712  (0.0746)	lr: 0.00777
# DEEPTB INFO    checkpoint saved as nnsk.iter85
# DEEPTB INFO    Epoch 85 summary:	train_loss: 0.0712
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep85
# DEEPTB INFO    iteration:86	train_loss: 0.0699  (0.0732)	lr: 0.007746
# DEEPTB INFO    checkpoint saved as nnsk.iter86
# DEEPTB INFO    Epoch 86 summary:	train_loss: 0.0699
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep86
# DEEPTB INFO    iteration:87	train_loss: 0.0687  (0.0718)	lr: 0.007723
# DEEPTB INFO    checkpoint saved as nnsk.iter87
# DEEPTB INFO    Epoch 87 summary:	train_loss: 0.0687
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep87
# DEEPTB INFO    iteration:88	train_loss: 0.0677  (0.0706)	lr: 0.0077
# DEEPTB INFO    checkpoint saved as nnsk.iter88
# DEEPTB INFO    Epoch 88 summary:	train_loss: 0.0677
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep88
# DEEPTB INFO    iteration:89	train_loss: 0.0666  (0.0694)	lr: 0.007677
# DEEPTB INFO    checkpoint saved as nnsk.iter89
# DEEPTB INFO    Epoch 89 summary:	train_loss: 0.0666
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep89
# DEEPTB INFO    iteration:90	train_loss: 0.0655  (0.0682)	lr: 0.007654
# DEEPTB INFO    checkpoint saved as nnsk.iter90
# DEEPTB INFO    Epoch 90 summary:	train_loss: 0.0655
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep90
# DEEPTB INFO    iteration:91	train_loss: 0.0644  (0.0671)	lr: 0.007631
# DEEPTB INFO    checkpoint saved as nnsk.iter91
# DEEPTB INFO    Epoch 91 summary:	train_loss: 0.0644
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep91
# DEEPTB INFO    iteration:92	train_loss: 0.0635  (0.0660)	lr: 0.007608
# DEEPTB INFO    checkpoint saved as nnsk.iter92
# DEEPTB INFO    Epoch 92 summary:	train_loss: 0.0635
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep92
# DEEPTB INFO    iteration:93	train_loss: 0.0626  (0.0650)	lr: 0.007585
# DEEPTB INFO    checkpoint saved as nnsk.iter93
# DEEPTB INFO    Epoch 93 summary:	train_loss: 0.0626
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep93
# DEEPTB INFO    iteration:94	train_loss: 0.0617  (0.0640)	lr: 0.007562
# DEEPTB INFO    checkpoint saved as nnsk.iter94
# DEEPTB INFO    Epoch 94 summary:	train_loss: 0.0617
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep94
# DEEPTB INFO    iteration:95	train_loss: 0.0607  (0.0630)	lr: 0.00754
# DEEPTB INFO    checkpoint saved as nnsk.iter95
# DEEPTB INFO    Epoch 95 summary:	train_loss: 0.0607
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep95
# DEEPTB INFO    iteration:96	train_loss: 0.0599  (0.0621)	lr: 0.007517
# DEEPTB INFO    checkpoint saved as nnsk.iter96
# DEEPTB INFO    Epoch 96 summary:	train_loss: 0.0599
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep96
# DEEPTB INFO    iteration:97	train_loss: 0.0591  (0.0612)	lr: 0.007494
# DEEPTB INFO    checkpoint saved as nnsk.iter97
# DEEPTB INFO    Epoch 97 summary:	train_loss: 0.0591
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep97
# DEEPTB INFO    iteration:98	train_loss: 0.0583  (0.0603)	lr: 0.007472
# DEEPTB INFO    checkpoint saved as nnsk.iter98
# DEEPTB INFO    Epoch 98 summary:	train_loss: 0.0583
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep98
# DEEPTB INFO    iteration:99	train_loss: 0.0575  (0.0594)	lr: 0.007449
# DEEPTB INFO    checkpoint saved as nnsk.iter99
# DEEPTB INFO    Epoch 99 summary:	train_loss: 0.0575
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep99
# DEEPTB INFO    iteration:100	train_loss: 0.0567  (0.0586)	lr: 0.007427
# DEEPTB INFO    checkpoint saved as nnsk.iter100
# DEEPTB INFO    Epoch 100 summary:	train_loss: 0.0567
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep100
# DEEPTB INFO    iteration:101	train_loss: 0.0559  (0.0578)	lr: 0.007405
# DEEPTB INFO    checkpoint saved as nnsk.iter101
# DEEPTB INFO    Epoch 101 summary:	train_loss: 0.0559
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep101
# DEEPTB INFO    iteration:102	train_loss: 0.0552  (0.0570)	lr: 0.007383
# DEEPTB INFO    checkpoint saved as nnsk.iter102
# DEEPTB INFO    Epoch 102 summary:	train_loss: 0.0552
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep102
# DEEPTB INFO    iteration:103	train_loss: 0.0545  (0.0563)	lr: 0.00736
# DEEPTB INFO    checkpoint saved as nnsk.iter103
# DEEPTB INFO    Epoch 103 summary:	train_loss: 0.0545
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep103
# DEEPTB INFO    iteration:104	train_loss: 0.0539  (0.0556)	lr: 0.007338
# DEEPTB INFO    checkpoint saved as nnsk.iter104
# DEEPTB INFO    Epoch 104 summary:	train_loss: 0.0539
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep104
# DEEPTB INFO    iteration:105	train_loss: 0.0532  (0.0549)	lr: 0.007316
# DEEPTB INFO    checkpoint saved as nnsk.iter105
# DEEPTB INFO    Epoch 105 summary:	train_loss: 0.0532
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep105
# DEEPTB INFO    iteration:106	train_loss: 0.0526  (0.0542)	lr: 0.007294
# DEEPTB INFO    checkpoint saved as nnsk.iter106
# DEEPTB INFO    Epoch 106 summary:	train_loss: 0.0526
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep106
# DEEPTB INFO    iteration:107	train_loss: 0.0520  (0.0535)	lr: 0.007273
# DEEPTB INFO    checkpoint saved as nnsk.iter107
# DEEPTB INFO    Epoch 107 summary:	train_loss: 0.0520
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep107
# DEEPTB INFO    iteration:108	train_loss: 0.0514  (0.0529)	lr: 0.007251
# DEEPTB INFO    checkpoint saved as nnsk.iter108
# DEEPTB INFO    Epoch 108 summary:	train_loss: 0.0514
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep108
# DEEPTB INFO    iteration:109	train_loss: 0.0508  (0.0523)	lr: 0.007229
# DEEPTB INFO    checkpoint saved as nnsk.iter109
# DEEPTB INFO    Epoch 109 summary:	train_loss: 0.0508
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep109
# DEEPTB INFO    iteration:110	train_loss: 0.0502  (0.0517)	lr: 0.007207
# DEEPTB INFO    checkpoint saved as nnsk.iter110
# DEEPTB INFO    Epoch 110 summary:	train_loss: 0.0502
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep110
# DEEPTB INFO    iteration:111	train_loss: 0.0497  (0.0511)	lr: 0.007186
# DEEPTB INFO    checkpoint saved as nnsk.iter111
# DEEPTB INFO    Epoch 111 summary:	train_loss: 0.0497
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep111
# DEEPTB INFO    iteration:112	train_loss: 0.0492  (0.0505)	lr: 0.007164
# DEEPTB INFO    checkpoint saved as nnsk.iter112
# DEEPTB INFO    Epoch 112 summary:	train_loss: 0.0492
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep112
# DEEPTB INFO    iteration:113	train_loss: 0.0487  (0.0500)	lr: 0.007143
# DEEPTB INFO    checkpoint saved as nnsk.iter113
# DEEPTB INFO    Epoch 113 summary:	train_loss: 0.0487
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep113
# DEEPTB INFO    iteration:114	train_loss: 0.0482  (0.0494)	lr: 0.007121
# DEEPTB INFO    checkpoint saved as nnsk.iter114
# DEEPTB INFO    Epoch 114 summary:	train_loss: 0.0482
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep114
# DEEPTB INFO    iteration:115	train_loss: 0.0477  (0.0489)	lr: 0.0071
# DEEPTB INFO    checkpoint saved as nnsk.iter115
# DEEPTB INFO    Epoch 115 summary:	train_loss: 0.0477
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep115
# DEEPTB INFO    iteration:116	train_loss: 0.0472  (0.0484)	lr: 0.007079
# DEEPTB INFO    checkpoint saved as nnsk.iter116
# DEEPTB INFO    Epoch 116 summary:	train_loss: 0.0472
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep116
# DEEPTB INFO    iteration:117	train_loss: 0.0467  (0.0479)	lr: 0.007057
# DEEPTB INFO    checkpoint saved as nnsk.iter117
# DEEPTB INFO    Epoch 117 summary:	train_loss: 0.0467
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep117
# DEEPTB INFO    iteration:118	train_loss: 0.0463  (0.0474)	lr: 0.007036
# DEEPTB INFO    checkpoint saved as nnsk.iter118
# DEEPTB INFO    Epoch 118 summary:	train_loss: 0.0463
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep118
# DEEPTB INFO    iteration:119	train_loss: 0.0458  (0.0469)	lr: 0.007015
# DEEPTB INFO    checkpoint saved as nnsk.iter119
# DEEPTB INFO    Epoch 119 summary:	train_loss: 0.0458
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep119
# DEEPTB INFO    iteration:120	train_loss: 0.0454  (0.0465)	lr: 0.006994
# DEEPTB INFO    checkpoint saved as nnsk.iter120
# DEEPTB INFO    Epoch 120 summary:	train_loss: 0.0454
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep120
# DEEPTB INFO    iteration:121	train_loss: 0.0449  (0.0460)	lr: 0.006973
# DEEPTB INFO    checkpoint saved as nnsk.iter121
# DEEPTB INFO    Epoch 121 summary:	train_loss: 0.0449
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep121
# DEEPTB INFO    iteration:122	train_loss: 0.0445  (0.0456)	lr: 0.006952
# DEEPTB INFO    checkpoint saved as nnsk.iter122
# DEEPTB INFO    Epoch 122 summary:	train_loss: 0.0445
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep122
# DEEPTB INFO    iteration:123	train_loss: 0.0441  (0.0451)	lr: 0.006931
# DEEPTB INFO    checkpoint saved as nnsk.iter123
# DEEPTB INFO    Epoch 123 summary:	train_loss: 0.0441
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep123
# DEEPTB INFO    iteration:124	train_loss: 0.0437  (0.0447)	lr: 0.00691
# DEEPTB INFO    checkpoint saved as nnsk.iter124
# DEEPTB INFO    Epoch 124 summary:	train_loss: 0.0437
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep124
# DEEPTB INFO    iteration:125	train_loss: 0.0433  (0.0443)	lr: 0.00689
# DEEPTB INFO    checkpoint saved as nnsk.iter125
# DEEPTB INFO    Epoch 125 summary:	train_loss: 0.0433
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep125
# DEEPTB INFO    iteration:126	train_loss: 0.0429  (0.0438)	lr: 0.006869
# DEEPTB INFO    checkpoint saved as nnsk.iter126
# DEEPTB INFO    Epoch 126 summary:	train_loss: 0.0429
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep126
# DEEPTB INFO    iteration:127	train_loss: 0.0425  (0.0434)	lr: 0.006848
# DEEPTB INFO    checkpoint saved as nnsk.iter127
# DEEPTB INFO    Epoch 127 summary:	train_loss: 0.0425
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep127
# DEEPTB INFO    iteration:128	train_loss: 0.0421  (0.0430)	lr: 0.006828
# DEEPTB INFO    checkpoint saved as nnsk.iter128
# DEEPTB INFO    Epoch 128 summary:	train_loss: 0.0421
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep128
# DEEPTB INFO    iteration:129	train_loss: 0.0417  (0.0426)	lr: 0.006807
# DEEPTB INFO    checkpoint saved as nnsk.iter129
# DEEPTB INFO    Epoch 129 summary:	train_loss: 0.0417
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep129
# DEEPTB INFO    iteration:130	train_loss: 0.0413  (0.0422)	lr: 0.006787
# DEEPTB INFO    checkpoint saved as nnsk.iter130
# DEEPTB INFO    Epoch 130 summary:	train_loss: 0.0413
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep130
# DEEPTB INFO    iteration:131	train_loss: 0.0409  (0.0418)	lr: 0.006767
# DEEPTB INFO    checkpoint saved as nnsk.iter131
# DEEPTB INFO    Epoch 131 summary:	train_loss: 0.0409
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep131
# DEEPTB INFO    iteration:132	train_loss: 0.0405  (0.0414)	lr: 0.006746
# DEEPTB INFO    checkpoint saved as nnsk.iter132
# DEEPTB INFO    Epoch 132 summary:	train_loss: 0.0405
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep132
# DEEPTB INFO    iteration:133	train_loss: 0.0401  (0.0410)	lr: 0.006726
# DEEPTB INFO    checkpoint saved as nnsk.iter133
# DEEPTB INFO    Epoch 133 summary:	train_loss: 0.0401
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep133
# DEEPTB INFO    iteration:134	train_loss: 0.0398  (0.0407)	lr: 0.006706
# DEEPTB INFO    checkpoint saved as nnsk.iter134
# DEEPTB INFO    Epoch 134 summary:	train_loss: 0.0398
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep134
# DEEPTB INFO    iteration:135	train_loss: 0.0394  (0.0403)	lr: 0.006686
# DEEPTB INFO    checkpoint saved as nnsk.iter135
# DEEPTB INFO    Epoch 135 summary:	train_loss: 0.0394
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep135
# DEEPTB INFO    iteration:136	train_loss: 0.0391  (0.0399)	lr: 0.006666
# DEEPTB INFO    checkpoint saved as nnsk.iter136
# DEEPTB INFO    Epoch 136 summary:	train_loss: 0.0391
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep136
# DEEPTB INFO    iteration:137	train_loss: 0.0387  (0.0396)	lr: 0.006646
# DEEPTB INFO    checkpoint saved as nnsk.iter137
# DEEPTB INFO    Epoch 137 summary:	train_loss: 0.0387
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep137
# DEEPTB INFO    iteration:138	train_loss: 0.0383  (0.0392)	lr: 0.006626
# DEEPTB INFO    checkpoint saved as nnsk.iter138
# DEEPTB INFO    Epoch 138 summary:	train_loss: 0.0383
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep138
# DEEPTB INFO    iteration:139	train_loss: 0.0380  (0.0388)	lr: 0.006606
# DEEPTB INFO    checkpoint saved as nnsk.iter139
# DEEPTB INFO    Epoch 139 summary:	train_loss: 0.0380
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep139
# DEEPTB INFO    iteration:140	train_loss: 0.0377  (0.0385)	lr: 0.006586
# DEEPTB INFO    checkpoint saved as nnsk.iter140
# DEEPTB INFO    Epoch 140 summary:	train_loss: 0.0377
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep140
# DEEPTB INFO    iteration:141	train_loss: 0.0373  (0.0381)	lr: 0.006566
# DEEPTB INFO    checkpoint saved as nnsk.iter141
# DEEPTB INFO    Epoch 141 summary:	train_loss: 0.0373
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep141
# DEEPTB INFO    iteration:142	train_loss: 0.0370  (0.0378)	lr: 0.006547
# DEEPTB INFO    checkpoint saved as nnsk.iter142
# DEEPTB INFO    Epoch 142 summary:	train_loss: 0.0370
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep142
# DEEPTB INFO    iteration:143	train_loss: 0.0367  (0.0375)	lr: 0.006527
# DEEPTB INFO    checkpoint saved as nnsk.iter143
# DEEPTB INFO    Epoch 143 summary:	train_loss: 0.0367
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep143
# DEEPTB INFO    iteration:144	train_loss: 0.0364  (0.0371)	lr: 0.006507
# DEEPTB INFO    checkpoint saved as nnsk.iter144
# DEEPTB INFO    Epoch 144 summary:	train_loss: 0.0364
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep144
# DEEPTB INFO    iteration:145	train_loss: 0.0360  (0.0368)	lr: 0.006488
# DEEPTB INFO    checkpoint saved as nnsk.iter145
# DEEPTB INFO    Epoch 145 summary:	train_loss: 0.0360
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep145
# DEEPTB INFO    iteration:146	train_loss: 0.0357  (0.0365)	lr: 0.006468
# DEEPTB INFO    checkpoint saved as nnsk.iter146
# DEEPTB INFO    Epoch 146 summary:	train_loss: 0.0357
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep146
# DEEPTB INFO    iteration:147	train_loss: 0.0354  (0.0362)	lr: 0.006449
# DEEPTB INFO    checkpoint saved as nnsk.iter147
# DEEPTB INFO    Epoch 147 summary:	train_loss: 0.0354
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep147
# DEEPTB INFO    iteration:148	train_loss: 0.0351  (0.0359)	lr: 0.00643
# DEEPTB INFO    checkpoint saved as nnsk.iter148
# DEEPTB INFO    Epoch 148 summary:	train_loss: 0.0351
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep148
# DEEPTB INFO    iteration:149	train_loss: 0.0348  (0.0356)	lr: 0.00641
# DEEPTB INFO    checkpoint saved as nnsk.iter149
# DEEPTB INFO    Epoch 149 summary:	train_loss: 0.0348
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep149
# DEEPTB INFO    iteration:150	train_loss: 0.0346  (0.0353)	lr: 0.006391
# DEEPTB INFO    checkpoint saved as nnsk.iter150
# DEEPTB INFO    Epoch 150 summary:	train_loss: 0.0346
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep150
# DEEPTB INFO    iteration:151	train_loss: 0.0343  (0.0350)	lr: 0.006372
# DEEPTB INFO    checkpoint saved as nnsk.iter151
# DEEPTB INFO    Epoch 151 summary:	train_loss: 0.0343
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep151
# DEEPTB INFO    iteration:152	train_loss: 0.0340  (0.0347)	lr: 0.006353
# DEEPTB INFO    checkpoint saved as nnsk.iter152
# DEEPTB INFO    Epoch 152 summary:	train_loss: 0.0340
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep152
# DEEPTB INFO    iteration:153	train_loss: 0.0337  (0.0344)	lr: 0.006334
# DEEPTB INFO    checkpoint saved as nnsk.iter153
# DEEPTB INFO    Epoch 153 summary:	train_loss: 0.0337
# ---------------------------------------------------------------------------------
# ...
# DEEPTB INFO    checkpoint saved as nnsk.iter448
# DEEPTB INFO    Epoch 448 summary:	train_loss: 0.0149
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep448
# DEEPTB INFO    iteration:449	train_loss: 0.0149  (0.0150)	lr: 0.002603
# DEEPTB INFO    checkpoint saved as nnsk.iter449
# DEEPTB INFO    Epoch 449 summary:	train_loss: 0.0149
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep449
# DEEPTB INFO    iteration:450	train_loss: 0.0149  (0.0149)	lr: 0.002595
# DEEPTB INFO    checkpoint saved as nnsk.iter450
# DEEPTB INFO    Epoch 450 summary:	train_loss: 0.0149
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep450
# DEEPTB INFO    iteration:451	train_loss: 0.0149  (0.0149)	lr: 0.002587
# DEEPTB INFO    checkpoint saved as nnsk.iter451
# DEEPTB INFO    Epoch 451 summary:	train_loss: 0.0149
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep451
# DEEPTB INFO    iteration:452	train_loss: 0.0149  (0.0149)	lr: 0.002579
# DEEPTB INFO    checkpoint saved as nnsk.iter452
# DEEPTB INFO    Epoch 452 summary:	train_loss: 0.0149
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep452
# DEEPTB INFO    iteration:453	train_loss: 0.0149  (0.0149)	lr: 0.002572
# DEEPTB INFO    checkpoint saved as nnsk.iter453
# DEEPTB INFO    Epoch 453 summary:	train_loss: 0.0149
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep453
# DEEPTB INFO    iteration:454	train_loss: 0.0149  (0.0149)	lr: 0.002564
# DEEPTB INFO    checkpoint saved as nnsk.iter454
# DEEPTB INFO    Epoch 454 summary:	train_loss: 0.0149
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep454
# DEEPTB INFO    iteration:455	train_loss: 0.0148  (0.0149)	lr: 0.002556
# DEEPTB INFO    checkpoint saved as nnsk.iter455
# DEEPTB INFO    Epoch 455 summary:	train_loss: 0.0148
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep455
# DEEPTB INFO    iteration:456	train_loss: 0.0148  (0.0149)	lr: 0.002549
# DEEPTB INFO    checkpoint saved as nnsk.iter456
# DEEPTB INFO    Epoch 456 summary:	train_loss: 0.0148
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep456
# DEEPTB INFO    iteration:457	train_loss: 0.0148  (0.0149)	lr: 0.002541
# DEEPTB INFO    checkpoint saved as nnsk.iter457
# DEEPTB INFO    Epoch 457 summary:	train_loss: 0.0148
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep457
# DEEPTB INFO    iteration:458	train_loss: 0.0148  (0.0148)	lr: 0.002533
# DEEPTB INFO    checkpoint saved as nnsk.iter458
# DEEPTB INFO    Epoch 458 summary:	train_loss: 0.0148
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep458
# DEEPTB INFO    iteration:459	train_loss: 0.0148  (0.0148)	lr: 0.002526
# DEEPTB INFO    checkpoint saved as nnsk.iter459
# DEEPTB INFO    Epoch 459 summary:	train_loss: 0.0148
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep459
# DEEPTB INFO    iteration:460	train_loss: 0.0148  (0.0148)	lr: 0.002518
# DEEPTB INFO    checkpoint saved as nnsk.iter460
# DEEPTB INFO    Epoch 460 summary:	train_loss: 0.0148
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep460
# DEEPTB INFO    iteration:461	train_loss: 0.0148  (0.0148)	lr: 0.002511
# DEEPTB INFO    checkpoint saved as nnsk.iter461
# DEEPTB INFO    Epoch 461 summary:	train_loss: 0.0148
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep461
# DEEPTB INFO    iteration:462	train_loss: 0.0148  (0.0148)	lr: 0.002503
# DEEPTB INFO    checkpoint saved as nnsk.iter462
# DEEPTB INFO    Epoch 462 summary:	train_loss: 0.0148
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep462
# DEEPTB INFO    iteration:463	train_loss: 0.0148  (0.0148)	lr: 0.002496
# DEEPTB INFO    checkpoint saved as nnsk.iter463
# DEEPTB INFO    Epoch 463 summary:	train_loss: 0.0148
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep463
# DEEPTB INFO    iteration:464	train_loss: 0.0147  (0.0148)	lr: 0.002488
# DEEPTB INFO    checkpoint saved as nnsk.iter464
# DEEPTB INFO    Epoch 464 summary:	train_loss: 0.0147
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep464
# DEEPTB INFO    iteration:465	train_loss: 0.0147  (0.0148)	lr: 0.002481
# DEEPTB INFO    checkpoint saved as nnsk.iter465
# DEEPTB INFO    Epoch 465 summary:	train_loss: 0.0147
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep465
# DEEPTB INFO    iteration:466	train_loss: 0.0147  (0.0147)	lr: 0.002473
# DEEPTB INFO    checkpoint saved as nnsk.iter466
# DEEPTB INFO    Epoch 466 summary:	train_loss: 0.0147
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep466
# DEEPTB INFO    iteration:467	train_loss: 0.0147  (0.0147)	lr: 0.002466
# DEEPTB INFO    checkpoint saved as nnsk.iter467
# DEEPTB INFO    Epoch 467 summary:	train_loss: 0.0147
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep467
# DEEPTB INFO    iteration:468	train_loss: 0.0147  (0.0147)	lr: 0.002458
# DEEPTB INFO    checkpoint saved as nnsk.iter468
# DEEPTB INFO    Epoch 468 summary:	train_loss: 0.0147
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep468
# DEEPTB INFO    iteration:469	train_loss: 0.0147  (0.0147)	lr: 0.002451
# DEEPTB INFO    checkpoint saved as nnsk.iter469
# DEEPTB INFO    Epoch 469 summary:	train_loss: 0.0147
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep469
# DEEPTB INFO    iteration:470	train_loss: 0.0147  (0.0147)	lr: 0.002444
# DEEPTB INFO    checkpoint saved as nnsk.iter470
# DEEPTB INFO    Epoch 470 summary:	train_loss: 0.0147
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep470
# DEEPTB INFO    iteration:471	train_loss: 0.0147  (0.0147)	lr: 0.002436
# DEEPTB INFO    checkpoint saved as nnsk.iter471
# DEEPTB INFO    Epoch 471 summary:	train_loss: 0.0147
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep471
# DEEPTB INFO    iteration:472	train_loss: 0.0146  (0.0147)	lr: 0.002429
# DEEPTB INFO    checkpoint saved as nnsk.iter472
# DEEPTB INFO    Epoch 472 summary:	train_loss: 0.0146
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep472
# DEEPTB INFO    iteration:473	train_loss: 0.0146  (0.0147)	lr: 0.002422
# DEEPTB INFO    checkpoint saved as nnsk.iter473
# DEEPTB INFO    Epoch 473 summary:	train_loss: 0.0146
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep473
# DEEPTB INFO    iteration:474	train_loss: 0.0146  (0.0146)	lr: 0.002414
# DEEPTB INFO    checkpoint saved as nnsk.iter474
# DEEPTB INFO    Epoch 474 summary:	train_loss: 0.0146
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep474
# DEEPTB INFO    iteration:475	train_loss: 0.0146  (0.0146)	lr: 0.002407
# DEEPTB INFO    checkpoint saved as nnsk.iter475
# DEEPTB INFO    Epoch 475 summary:	train_loss: 0.0146
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep475
# DEEPTB INFO    iteration:476	train_loss: 0.0146  (0.0146)	lr: 0.0024
# DEEPTB INFO    checkpoint saved as nnsk.iter476
# DEEPTB INFO    Epoch 476 summary:	train_loss: 0.0146
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep476
# DEEPTB INFO    iteration:477	train_loss: 0.0146  (0.0146)	lr: 0.002393
# DEEPTB INFO    checkpoint saved as nnsk.iter477
# DEEPTB INFO    Epoch 477 summary:	train_loss: 0.0146
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep477
# DEEPTB INFO    iteration:478	train_loss: 0.0146  (0.0146)	lr: 0.002386
# DEEPTB INFO    checkpoint saved as nnsk.iter478
# DEEPTB INFO    Epoch 478 summary:	train_loss: 0.0146
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep478
# DEEPTB INFO    iteration:479	train_loss: 0.0146  (0.0146)	lr: 0.002378
# DEEPTB INFO    checkpoint saved as nnsk.iter479
# DEEPTB INFO    Epoch 479 summary:	train_loss: 0.0146
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep479
# DEEPTB INFO    iteration:480	train_loss: 0.0146  (0.0146)	lr: 0.002371
# DEEPTB INFO    checkpoint saved as nnsk.iter480
# DEEPTB INFO    Epoch 480 summary:	train_loss: 0.0146
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep480
# DEEPTB INFO    iteration:481	train_loss: 0.0145  (0.0146)	lr: 0.002364
# DEEPTB INFO    checkpoint saved as nnsk.iter481
# DEEPTB INFO    Epoch 481 summary:	train_loss: 0.0145
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep481
# DEEPTB INFO    iteration:482	train_loss: 0.0145  (0.0146)	lr: 0.002357
# DEEPTB INFO    checkpoint saved as nnsk.iter482
# DEEPTB INFO    Epoch 482 summary:	train_loss: 0.0145
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep482
# DEEPTB INFO    iteration:483	train_loss: 0.0145  (0.0145)	lr: 0.00235
# DEEPTB INFO    checkpoint saved as nnsk.iter483
# DEEPTB INFO    Epoch 483 summary:	train_loss: 0.0145
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep483
# DEEPTB INFO    iteration:484	train_loss: 0.0145  (0.0145)	lr: 0.002343
# DEEPTB INFO    checkpoint saved as nnsk.iter484
# DEEPTB INFO    Epoch 484 summary:	train_loss: 0.0145
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep484
# DEEPTB INFO    iteration:485	train_loss: 0.0145  (0.0145)	lr: 0.002336
# DEEPTB INFO    checkpoint saved as nnsk.iter485
# DEEPTB INFO    Epoch 485 summary:	train_loss: 0.0145
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep485
# DEEPTB INFO    iteration:486	train_loss: 0.0145  (0.0145)	lr: 0.002329
# DEEPTB INFO    checkpoint saved as nnsk.iter486
# DEEPTB INFO    Epoch 486 summary:	train_loss: 0.0145
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep486
# DEEPTB INFO    iteration:487	train_loss: 0.0145  (0.0145)	lr: 0.002322
# DEEPTB INFO    checkpoint saved as nnsk.iter487
# DEEPTB INFO    Epoch 487 summary:	train_loss: 0.0145
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep487
# DEEPTB INFO    iteration:488	train_loss: 0.0145  (0.0145)	lr: 0.002315
# DEEPTB INFO    checkpoint saved as nnsk.iter488
# DEEPTB INFO    Epoch 488 summary:	train_loss: 0.0145
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep488
# DEEPTB INFO    iteration:489	train_loss: 0.0145  (0.0145)	lr: 0.002308
# DEEPTB INFO    checkpoint saved as nnsk.iter489
# DEEPTB INFO    Epoch 489 summary:	train_loss: 0.0145
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep489
# DEEPTB INFO    iteration:490	train_loss: 0.0144  (0.0145)	lr: 0.002301
# DEEPTB INFO    checkpoint saved as nnsk.iter490
# DEEPTB INFO    Epoch 490 summary:	train_loss: 0.0144
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep490
# DEEPTB INFO    iteration:491	train_loss: 0.0144  (0.0145)	lr: 0.002294
# DEEPTB INFO    checkpoint saved as nnsk.iter491
# DEEPTB INFO    Epoch 491 summary:	train_loss: 0.0144
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep491
# DEEPTB INFO    iteration:492	train_loss: 0.0144  (0.0144)	lr: 0.002287
# DEEPTB INFO    checkpoint saved as nnsk.iter492
# DEEPTB INFO    Epoch 492 summary:	train_loss: 0.0144
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep492
# DEEPTB INFO    iteration:493	train_loss: 0.0144  (0.0144)	lr: 0.00228
# DEEPTB INFO    checkpoint saved as nnsk.iter493
# DEEPTB INFO    Epoch 493 summary:	train_loss: 0.0144
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep493
# DEEPTB INFO    iteration:494	train_loss: 0.0144  (0.0144)	lr: 0.002274
# DEEPTB INFO    checkpoint saved as nnsk.iter494
# DEEPTB INFO    Epoch 494 summary:	train_loss: 0.0144
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep494
# DEEPTB INFO    iteration:495	train_loss: 0.0144  (0.0144)	lr: 0.002267
# DEEPTB INFO    checkpoint saved as nnsk.iter495
# DEEPTB INFO    Epoch 495 summary:	train_loss: 0.0144
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep495
# DEEPTB INFO    iteration:496	train_loss: 0.0144  (0.0144)	lr: 0.00226
# DEEPTB INFO    checkpoint saved as nnsk.iter496
# DEEPTB INFO    Epoch 496 summary:	train_loss: 0.0144
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep496
# DEEPTB INFO    iteration:497	train_loss: 0.0144  (0.0144)	lr: 0.002253
# DEEPTB INFO    checkpoint saved as nnsk.iter497
# DEEPTB INFO    Epoch 497 summary:	train_loss: 0.0144
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep497
# DEEPTB INFO    iteration:498	train_loss: 0.0144  (0.0144)	lr: 0.002246
# DEEPTB INFO    checkpoint saved as nnsk.iter498
# DEEPTB INFO    Epoch 498 summary:	train_loss: 0.0144
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep498
# DEEPTB INFO    iteration:499	train_loss: 0.0143  (0.0144)	lr: 0.00224
# DEEPTB INFO    checkpoint saved as nnsk.iter499
# DEEPTB INFO    Epoch 499 summary:	train_loss: 0.0143
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep499
# DEEPTB INFO    iteration:500	train_loss: 0.0143  (0.0144)	lr: 0.002233
# DEEPTB INFO    checkpoint saved as nnsk.iter500
# DEEPTB INFO    Epoch 500 summary:	train_loss: 0.0143
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep500
# DEEPTB INFO    finished training
# DEEPTB INFO    wall time: 43.033 s

# %%
# !dptb run band.json -i ./nnsk/checkpoint/nnsk.best.pth -o band_train
# !dptb run band.json -i ./ref_ckpt/nnsk_tr1.pth -o band_train

# display the band plot:
image_path = f'./band_train/results/band.png'
img = mpimg.imread(image_path)
plt.figure(figsize=(10, 8))
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# TBPLaS is not installed. Thus the TBPLaS is not available, Please install it first.
#
#
# #################################################################################
# #                                                                               #
# #                                                                               #
# #      ██████████                     ███████████  ███████████ ███████████      #
# #     ░░███░░░░███                   ░░███░░░░░███░█░░░███░░░█░░███░░░░░███     #
# #      ░███   ░░███  ██████   ██████  ░███    ░███░   ░███  ░  ░███    ░███     #
# #      ░███    ░███ ███░░███ ███░░███ ░██████████     ░███     ░██████████      #
# #      ░███    ░███░███████ ░███████  ░███░░░░░░      ░███     ░███░░░░░███     #
# #      ░███    ███ ░███░░░  ░███░░░   ░███            ░███     ░███    ░███     #
# #      ██████████  ░░██████ ░░██████  █████           █████    ███████████      #
# #     ░░░░░░░░░░    ░░░░░░   ░░░░░░  ░░░░░           ░░░░░    ░░░░░░░░░░░       #
# #                                                                               #
# #                         Version: 2.2.1.dev20+bcb3cf2                          #
# #                                                                               #
# #################################################################################
#
#
# DEEPTB INFO    The ['overlap_param'] are frozen!
# DEEPTB INFO    The ['overlap_param'] are frozen!
# DEEPTB WARNING Warning! structure is not set in run option, read from input config file.
# /Users/aisiqg/Software/venv/pydptb/lib/python3.9/site-packages/torch/nested/__init__.py:58: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/NestedTensorImpl.cpp:180.)
#   return torch._nested_tensor_from_tensor_list(tensor_list, dtype, None, device, None)
# DEEPTB INFO    KPOINTS  klist: 180 kpoints
# DEEPTB INFO    The eigenvalues are already in data. will use them.
# DEEPTB INFO    Calculating Fermi energy in the case of spin-degeneracy.
# DEEPTB INFO    Fermi energy converged after 26 iterations.
# DEEPTB INFO    q_cal: 7.999999999851121, total_electrons: 8.0, diff q: 1.488791312453941e-10
# DEEPTB INFO    Estimated E_fermi: -5.508924220035507 based on the valence electrons setting nel_atom : {'As': 5, 'Ga': 3} .
# DEEPTB INFO    No Fermi energy provided, using estimated value: -5.5089 eV
# Figure(640x560)
# DEEPTB INFO    band calculation successfully completed.

# %% [markdown]
# We can also continue training from the previous step's training results for one more round.

# %%
# !dptb train input.json -i ./nnsk/checkpoint/nnsk.best.pth -o nnsk2
# Out:
# TBPLaS is not installed. Thus the TBPLaS is not available, Please install it first.
#
#
# #################################################################################
# #                                                                               #
# #                                                                               #
# #      ██████████                     ███████████  ███████████ ███████████      #
# #     ░░███░░░░███                   ░░███░░░░░███░█░░░███░░░█░░███░░░░░███     #
# #      ░███   ░░███  ██████   ██████  ░███    ░███░   ░███  ░  ░███    ░███     #
# #      ░███    ░███ ███░░███ ███░░███ ░██████████     ░███     ░██████████      #
# #      ░███    ░███░███████ ░███████  ░███░░░░░░      ░███     ░███░░░░░███     #
# #      ░███    ███ ░███░░░  ░███░░░   ░███            ░███     ░███    ░███     #
# #      ██████████  ░░██████ ░░██████  █████           █████    ███████████      #
# #     ░░░░░░░░░░    ░░░░░░   ░░░░░░  ░░░░░           ░░░░░    ░░░░░░░░░░░       #
# #                                                                               #
# #                         Version: 2.2.1.dev20+bcb3cf2                          #
# #                                                                               #
# #################################################################################
#
#
# DEEPTB INFO    ------------------------------------------------------------------
# DEEPTB INFO         Cutoff options:
# DEEPTB INFO
# DEEPTB INFO         r_max            : {'Ga-Ga': 6.220000000000001, 'Ga-As': 6.43, 'As-Ga': 6.43, 'As-As': 6.630000000000001}
# DEEPTB INFO         er_max           : None
# DEEPTB INFO         oer_max          : None
# DEEPTB INFO    ------------------------------------------------------------------
# /Users/aisiqg/Software/venv/pydptb/lib/python3.9/site-packages/torch/nested/__init__.py:58: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/NestedTensorImpl.cpp:180.)
#   return torch._nested_tensor_from_tensor_list(tensor_list, dtype, None, device, None)
# DEEPTB WARNING The cutoffs in data and model are not checked. be careful!
# DEEPTB INFO    The ['overlap_param'] are frozen!
# DEEPTB INFO    The ['overlap_param'] are frozen!
# DEEPTB INFO    Model parameters: 246,  |    (About 0.25K)  |    (About 0.000M)  |    (About 0.0000B)
# DEEPTB INFO    iteration:1	train_loss: 0.0143  (0.0043)	lr: 0.01
# DEEPTB INFO    checkpoint saved as nnsk.iter1
# DEEPTB INFO    Epoch 1 summary:	train_loss: 0.0143
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep1
# DEEPTB INFO    iteration:2	train_loss: 0.0152  (0.0076)	lr: 0.00997
# DEEPTB INFO    checkpoint saved as nnsk.iter2
# DEEPTB INFO    Epoch 2 summary:	train_loss: 0.0152
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:3	train_loss: 0.0721  (0.0269)	lr: 0.00994
# DEEPTB INFO    checkpoint saved as nnsk.iter3
# DEEPTB INFO    Epoch 3 summary:	train_loss: 0.0721
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:4	train_loss: 0.0205  (0.0250)	lr: 0.00991
# DEEPTB INFO    checkpoint saved as nnsk.iter4
# DEEPTB INFO    Epoch 4 summary:	train_loss: 0.0205
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:5	train_loss: 0.0563  (0.0344)	lr: 0.009881
# DEEPTB INFO    checkpoint saved as nnsk.iter5
# DEEPTB INFO    Epoch 5 summary:	train_loss: 0.0563
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:6	train_loss: 0.0422  (0.0367)	lr: 0.009851
# DEEPTB INFO    checkpoint saved as nnsk.iter6
# DEEPTB INFO    Epoch 6 summary:	train_loss: 0.0422
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:7	train_loss: 0.0188  (0.0314)	lr: 0.009821
# DEEPTB INFO    checkpoint saved as nnsk.iter7
# DEEPTB INFO    Epoch 7 summary:	train_loss: 0.0188
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:8	train_loss: 0.0259  (0.0297)	lr: 0.009792
# DEEPTB INFO    checkpoint saved as nnsk.iter8
# DEEPTB INFO    Epoch 8 summary:	train_loss: 0.0259
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:9	train_loss: 0.0367  (0.0318)	lr: 0.009763
# DEEPTB INFO    checkpoint saved as nnsk.iter9
# DEEPTB INFO    Epoch 9 summary:	train_loss: 0.0367
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:10	train_loss: 0.0287  (0.0309)	lr: 0.009733
# DEEPTB INFO    checkpoint saved as nnsk.iter10
# DEEPTB INFO    Epoch 10 summary:	train_loss: 0.0287
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:11	train_loss: 0.0182  (0.0271)	lr: 0.009704
# DEEPTB INFO    checkpoint saved as nnsk.iter11
# DEEPTB INFO    Epoch 11 summary:	train_loss: 0.0182
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:12	train_loss: 0.0193  (0.0248)	lr: 0.009675
# DEEPTB INFO    checkpoint saved as nnsk.iter12
# DEEPTB INFO    Epoch 12 summary:	train_loss: 0.0193
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:13	train_loss: 0.0247  (0.0247)	lr: 0.009646
# DEEPTB INFO    checkpoint saved as nnsk.iter13
# DEEPTB INFO    Epoch 13 summary:	train_loss: 0.0247
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:14	train_loss: 0.0223  (0.0240)	lr: 0.009617
# DEEPTB INFO    checkpoint saved as nnsk.iter14
# DEEPTB INFO    Epoch 14 summary:	train_loss: 0.0223
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:15	train_loss: 0.0164  (0.0217)	lr: 0.009588
# DEEPTB INFO    checkpoint saved as nnsk.iter15
# DEEPTB INFO    Epoch 15 summary:	train_loss: 0.0164
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:16	train_loss: 0.0158  (0.0199)	lr: 0.009559
# DEEPTB INFO    checkpoint saved as nnsk.iter16
# DEEPTB INFO    Epoch 16 summary:	train_loss: 0.0158
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:17	train_loss: 0.0192  (0.0197)	lr: 0.009531
# DEEPTB INFO    checkpoint saved as nnsk.iter17
# DEEPTB INFO    Epoch 17 summary:	train_loss: 0.0192
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:18	train_loss: 0.0194  (0.0196)	lr: 0.009502
# DEEPTB INFO    checkpoint saved as nnsk.iter18
# DEEPTB INFO    Epoch 18 summary:	train_loss: 0.0194
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:19	train_loss: 0.0155  (0.0184)	lr: 0.009474
# DEEPTB INFO    checkpoint saved as nnsk.iter19
# DEEPTB INFO    Epoch 19 summary:	train_loss: 0.0155
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:20	train_loss: 0.0133  (0.0169)	lr: 0.009445
# DEEPTB INFO    checkpoint saved as nnsk.iter20
# DEEPTB INFO    Epoch 20 summary:	train_loss: 0.0133
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep20
# DEEPTB INFO    iteration:21	train_loss: 0.0150  (0.0163)	lr: 0.009417
# DEEPTB INFO    checkpoint saved as nnsk.iter21
# DEEPTB INFO    Epoch 21 summary:	train_loss: 0.0150
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:22	train_loss: 0.0167  (0.0164)	lr: 0.009389
# DEEPTB INFO    checkpoint saved as nnsk.iter22
# DEEPTB INFO    Epoch 22 summary:	train_loss: 0.0167
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:23	train_loss: 0.0153  (0.0161)	lr: 0.00936
# DEEPTB INFO    checkpoint saved as nnsk.iter23
# DEEPTB INFO    Epoch 23 summary:	train_loss: 0.0153
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:24	train_loss: 0.0127  (0.0151)	lr: 0.009332
# DEEPTB INFO    checkpoint saved as nnsk.iter24
# DEEPTB INFO    Epoch 24 summary:	train_loss: 0.0127
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep24
# DEEPTB INFO    iteration:25	train_loss: 0.0123  (0.0142)	lr: 0.009304
# DEEPTB INFO    checkpoint saved as nnsk.iter25
# DEEPTB INFO    Epoch 25 summary:	train_loss: 0.0123
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep25
# DEEPTB INFO    iteration:26	train_loss: 0.0139  (0.0142)	lr: 0.009276
# DEEPTB INFO    checkpoint saved as nnsk.iter26
# DEEPTB INFO    Epoch 26 summary:	train_loss: 0.0139
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:27	train_loss: 0.0144  (0.0142)	lr: 0.009249
# DEEPTB INFO    checkpoint saved as nnsk.iter27
# DEEPTB INFO    Epoch 27 summary:	train_loss: 0.0144
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:28	train_loss: 0.0128  (0.0138)	lr: 0.009221
# DEEPTB INFO    checkpoint saved as nnsk.iter28
# DEEPTB INFO    Epoch 28 summary:	train_loss: 0.0128
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:29	train_loss: 0.0117  (0.0132)	lr: 0.009193
# DEEPTB INFO    checkpoint saved as nnsk.iter29
# DEEPTB INFO    Epoch 29 summary:	train_loss: 0.0117
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep29
# DEEPTB INFO    iteration:30	train_loss: 0.0123  (0.0129)	lr: 0.009166
# DEEPTB INFO    checkpoint saved as nnsk.iter30
# DEEPTB INFO    Epoch 30 summary:	train_loss: 0.0123
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:31	train_loss: 0.0129  (0.0129)	lr: 0.009138
# DEEPTB INFO    checkpoint saved as nnsk.iter31
# DEEPTB INFO    Epoch 31 summary:	train_loss: 0.0129
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:32	train_loss: 0.0122  (0.0127)	lr: 0.009111
# DEEPTB INFO    checkpoint saved as nnsk.iter32
# DEEPTB INFO    Epoch 32 summary:	train_loss: 0.0122
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:33	train_loss: 0.0112  (0.0122)	lr: 0.009083
# DEEPTB INFO    checkpoint saved as nnsk.iter33
# DEEPTB INFO    Epoch 33 summary:	train_loss: 0.0112
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep33
# DEEPTB INFO    iteration:34	train_loss: 0.0113  (0.0120)	lr: 0.009056
# DEEPTB INFO    checkpoint saved as nnsk.iter34
# DEEPTB INFO    Epoch 34 summary:	train_loss: 0.0113
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:35	train_loss: 0.0120  (0.0120)	lr: 0.009029
# DEEPTB INFO    checkpoint saved as nnsk.iter35
# DEEPTB INFO    Epoch 35 summary:	train_loss: 0.0120
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:36	train_loss: 0.0118  (0.0119)	lr: 0.009002
# DEEPTB INFO    checkpoint saved as nnsk.iter36
# DEEPTB INFO    Epoch 36 summary:	train_loss: 0.0118
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:37	train_loss: 0.0109  (0.0116)	lr: 0.008975
# DEEPTB INFO    checkpoint saved as nnsk.iter37
# DEEPTB INFO    Epoch 37 summary:	train_loss: 0.0109
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep37
# DEEPTB INFO    iteration:38	train_loss: 0.0106  (0.0113)	lr: 0.008948
# DEEPTB INFO    checkpoint saved as nnsk.iter38
# DEEPTB INFO    Epoch 38 summary:	train_loss: 0.0106
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep38
# DEEPTB INFO    iteration:39	train_loss: 0.0111  (0.0112)	lr: 0.008921
# DEEPTB INFO    checkpoint saved as nnsk.iter39
# DEEPTB INFO    Epoch 39 summary:	train_loss: 0.0111
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:40	train_loss: 0.0112  (0.0112)	lr: 0.008894
# DEEPTB INFO    checkpoint saved as nnsk.iter40
# DEEPTB INFO    Epoch 40 summary:	train_loss: 0.0112
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:41	train_loss: 0.0107  (0.0111)	lr: 0.008868
# DEEPTB INFO    checkpoint saved as nnsk.iter41
# DEEPTB INFO    Epoch 41 summary:	train_loss: 0.0107
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:42	train_loss: 0.0103  (0.0108)	lr: 0.008841
# DEEPTB INFO    checkpoint saved as nnsk.iter42
# DEEPTB INFO    Epoch 42 summary:	train_loss: 0.0103
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep42
# DEEPTB INFO    iteration:43	train_loss: 0.0104  (0.0107)	lr: 0.008814
# DEEPTB INFO    checkpoint saved as nnsk.iter43
# DEEPTB INFO    Epoch 43 summary:	train_loss: 0.0104
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:44	train_loss: 0.0106  (0.0107)	lr: 0.008788
# DEEPTB INFO    checkpoint saved as nnsk.iter44
# DEEPTB INFO    Epoch 44 summary:	train_loss: 0.0106
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:45	train_loss: 0.0103  (0.0106)	lr: 0.008762
# DEEPTB INFO    checkpoint saved as nnsk.iter45
# DEEPTB INFO    Epoch 45 summary:	train_loss: 0.0103
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:46	train_loss: 0.0100  (0.0104)	lr: 0.008735
# DEEPTB INFO    checkpoint saved as nnsk.iter46
# DEEPTB INFO    Epoch 46 summary:	train_loss: 0.0100
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep46
# DEEPTB INFO    iteration:47	train_loss: 0.0101  (0.0103)	lr: 0.008709
# DEEPTB INFO    checkpoint saved as nnsk.iter47
# DEEPTB INFO    Epoch 47 summary:	train_loss: 0.0101
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:48	train_loss: 0.0101  (0.0103)	lr: 0.008683
# DEEPTB INFO    checkpoint saved as nnsk.iter48
# DEEPTB INFO    Epoch 48 summary:	train_loss: 0.0101
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:49	train_loss: 0.0100  (0.0102)	lr: 0.008657
# DEEPTB INFO    checkpoint saved as nnsk.iter49
# DEEPTB INFO    Epoch 49 summary:	train_loss: 0.0100
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep49
# DEEPTB INFO    iteration:50	train_loss: 0.0097  (0.0100)	lr: 0.008631
# DEEPTB INFO    checkpoint saved as nnsk.iter50
# DEEPTB INFO    Epoch 50 summary:	train_loss: 0.0097
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep50
# DEEPTB INFO    iteration:51	train_loss: 0.0097  (0.0099)	lr: 0.008605
# DEEPTB INFO    checkpoint saved as nnsk.iter51
# DEEPTB INFO    Epoch 51 summary:	train_loss: 0.0097
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep51
# DEEPTB INFO    iteration:52	train_loss: 0.0098  (0.0099)	lr: 0.008579
# DEEPTB INFO    checkpoint saved as nnsk.iter52
# DEEPTB INFO    Epoch 52 summary:	train_loss: 0.0098
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:53	train_loss: 0.0096  (0.0098)	lr: 0.008554
# DEEPTB INFO    checkpoint saved as nnsk.iter53
# DEEPTB INFO    Epoch 53 summary:	train_loss: 0.0096
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep53
# DEEPTB INFO    iteration:54	train_loss: 0.0094  (0.0097)	lr: 0.008528
# DEEPTB INFO    checkpoint saved as nnsk.iter54
# DEEPTB INFO    Epoch 54 summary:	train_loss: 0.0094
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep54
# DEEPTB INFO    iteration:55	train_loss: 0.0094  (0.0096)	lr: 0.008502
# DEEPTB INFO    checkpoint saved as nnsk.iter55
# DEEPTB INFO    Epoch 55 summary:	train_loss: 0.0094
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep55
# DEEPTB INFO    iteration:56	train_loss: 0.0095  (0.0096)	lr: 0.008477
# DEEPTB INFO    checkpoint saved as nnsk.iter56
# DEEPTB INFO    Epoch 56 summary:	train_loss: 0.0095
# ---------------------------------------------------------------------------------
# DEEPTB INFO    iteration:57	train_loss: 0.0094  (0.0095)	lr: 0.008451
# DEEPTB INFO    checkpoint saved as nnsk.iter57
# DEEPTB INFO    Epoch 57 summary:	train_loss: 0.0094
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep57
# DEEPTB INFO    iteration:58	train_loss: 0.0092  (0.0094)	lr: 0.008426
# DEEPTB INFO    checkpoint saved as nnsk.iter58
# DEEPTB INFO    Epoch 58 summary:	train_loss: 0.0092
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep58
# DEEPTB INFO    iteration:59	train_loss: 0.0092  (0.0093)	lr: 0.008401
# DEEPTB INFO    checkpoint saved as nnsk.iter59
# DEEPTB INFO    Epoch 59 summary:	train_loss: 0.0092
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep59
# DEEPTB INFO    iteration:60	train_loss: 0.0092  (0.0093)	lr: 0.008376
# DEEPTB INFO    checkpoint saved as nnsk.iter60
# DEEPTB INFO    Epoch 60 summary:	train_loss: 0.0092
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep60
# DEEPTB INFO    iteration:61	train_loss: 0.0091  (0.0092)	lr: 0.00835
# DEEPTB INFO    checkpoint saved as nnsk.iter61
# DEEPTB INFO    Epoch 61 summary:	train_loss: 0.0091
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep61
# DEEPTB INFO    iteration:62	train_loss: 0.0090  (0.0091)	lr: 0.008325
# DEEPTB INFO    checkpoint saved as nnsk.iter62
# DEEPTB INFO    Epoch 62 summary:	train_loss: 0.0090
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep62
# DEEPTB INFO    iteration:63	train_loss: 0.0089  (0.0091)	lr: 0.0083
# DEEPTB INFO    checkpoint saved as nnsk.iter63
# DEEPTB INFO    Epoch 63 summary:	train_loss: 0.0089
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep63
# DEEPTB INFO    iteration:64	train_loss: 0.0089  (0.0090)	lr: 0.008276
# DEEPTB INFO    checkpoint saved as nnsk.iter64
# DEEPTB INFO    Epoch 64 summary:	train_loss: 0.0089
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep64
# DEEPTB INFO    iteration:65	train_loss: 0.0088  (0.0090)	lr: 0.008251
# DEEPTB INFO    checkpoint saved as nnsk.iter65
# DEEPTB INFO    Epoch 65 summary:	train_loss: 0.0088
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep65
# DEEPTB INFO    iteration:66	train_loss: 0.0087  (0.0089)	lr: 0.008226
# DEEPTB INFO    checkpoint saved as nnsk.iter66
# DEEPTB INFO    Epoch 66 summary:	train_loss: 0.0087
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep66
# DEEPTB INFO    iteration:67	train_loss: 0.0087  (0.0088)	lr: 0.008201
# DEEPTB INFO    checkpoint saved as nnsk.iter67
# DEEPTB INFO    Epoch 67 summary:	train_loss: 0.0087
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep67
# DEEPTB INFO    iteration:68	train_loss: 0.0087  (0.0088)	lr: 0.008177
# DEEPTB INFO    checkpoint saved as nnsk.iter68
# DEEPTB INFO    Epoch 68 summary:	train_loss: 0.0087
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep68
# DEEPTB INFO    iteration:69	train_loss: 0.0086  (0.0087)	lr: 0.008152
# DEEPTB INFO    checkpoint saved as nnsk.iter69
# DEEPTB INFO    Epoch 69 summary:	train_loss: 0.0086
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep69
# DEEPTB INFO    iteration:70	train_loss: 0.0085  (0.0087)	lr: 0.008128
# DEEPTB INFO    checkpoint saved as nnsk.iter70
# DEEPTB INFO    Epoch 70 summary:	train_loss: 0.0085
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep70
# DEEPTB INFO    iteration:71	train_loss: 0.0085  (0.0086)	lr: 0.008103
# DEEPTB INFO    checkpoint saved as nnsk.iter71
# DEEPTB INFO    Epoch 71 summary:	train_loss: 0.0085
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep71
# DEEPTB INFO    iteration:72	train_loss: 0.0085  (0.0086)	lr: 0.008079
# DEEPTB INFO    checkpoint saved as nnsk.iter72
# DEEPTB INFO    Epoch 72 summary:	train_loss: 0.0085
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep72
# DEEPTB INFO    iteration:73	train_loss: 0.0084  (0.0085)	lr: 0.008055
# DEEPTB INFO    checkpoint saved as nnsk.iter73
# DEEPTB INFO    Epoch 73 summary:	train_loss: 0.0084
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep73
# DEEPTB INFO    iteration:74	train_loss: 0.0083  (0.0085)	lr: 0.008031
# DEEPTB INFO    checkpoint saved as nnsk.iter74
# DEEPTB INFO    Epoch 74 summary:	train_loss: 0.0083
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep74
# DEEPTB INFO    iteration:75	train_loss: 0.0083  (0.0084)	lr: 0.008006
# DEEPTB INFO    checkpoint saved as nnsk.iter75
# DEEPTB INFO    Epoch 75 summary:	train_loss: 0.0083
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep75
# DEEPTB INFO    iteration:76	train_loss: 0.0083  (0.0084)	lr: 0.007982
# DEEPTB INFO    checkpoint saved as nnsk.iter76
# DEEPTB INFO    Epoch 76 summary:	train_loss: 0.0083
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep76
# DEEPTB INFO    iteration:77	train_loss: 0.0082  (0.0083)	lr: 0.007959
# DEEPTB INFO    checkpoint saved as nnsk.iter77
# DEEPTB INFO    Epoch 77 summary:	train_loss: 0.0082
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep77
# DEEPTB INFO    iteration:78	train_loss: 0.0082  (0.0083)	lr: 0.007935
# DEEPTB INFO    checkpoint saved as nnsk.iter78
# DEEPTB INFO    Epoch 78 summary:	train_loss: 0.0082
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep78
# DEEPTB INFO    iteration:79	train_loss: 0.0081  (0.0082)	lr: 0.007911
# DEEPTB INFO    checkpoint saved as nnsk.iter79
# DEEPTB INFO    Epoch 79 summary:	train_loss: 0.0081
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep79
# DEEPTB INFO    iteration:80	train_loss: 0.0081  (0.0082)	lr: 0.007887
# DEEPTB INFO    checkpoint saved as nnsk.iter80
# DEEPTB INFO    Epoch 80 summary:	train_loss: 0.0081
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep80
# DEEPTB INFO    iteration:81	train_loss: 0.0080  (0.0081)	lr: 0.007863
# DEEPTB INFO    checkpoint saved as nnsk.iter81
# DEEPTB INFO    Epoch 81 summary:	train_loss: 0.0080
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep81
# DEEPTB INFO    iteration:82	train_loss: 0.0080  (0.0081)	lr: 0.00784
# DEEPTB INFO    checkpoint saved as nnsk.iter82
# DEEPTB INFO    Epoch 82 summary:	train_loss: 0.0080
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep82
# DEEPTB INFO    iteration:83	train_loss: 0.0079  (0.0080)	lr: 0.007816
# DEEPTB INFO    checkpoint saved as nnsk.iter83
# DEEPTB INFO    Epoch 83 summary:	train_loss: 0.0079
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep83
# DEEPTB INFO    iteration:84	train_loss: 0.0079  (0.0080)	lr: 0.007793
# DEEPTB INFO    checkpoint saved as nnsk.iter84
# DEEPTB INFO    Epoch 84 summary:	train_loss: 0.0079
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep84
# DEEPTB INFO    iteration:85	train_loss: 0.0079  (0.0080)	lr: 0.00777
# DEEPTB INFO    checkpoint saved as nnsk.iter85
# DEEPTB INFO    Epoch 85 summary:	train_loss: 0.0079
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep85
# DEEPTB INFO    iteration:86	train_loss: 0.0078  (0.0079)	lr: 0.007746
# DEEPTB INFO    checkpoint saved as nnsk.iter86
# DEEPTB INFO    Epoch 86 summary:	train_loss: 0.0078
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep86
# DEEPTB INFO    iteration:87	train_loss: 0.0078  (0.0079)	lr: 0.007723
# DEEPTB INFO    checkpoint saved as nnsk.iter87
# DEEPTB INFO    Epoch 87 summary:	train_loss: 0.0078
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep87
# DEEPTB INFO    iteration:88	train_loss: 0.0077  (0.0078)	lr: 0.0077
# DEEPTB INFO    checkpoint saved as nnsk.iter88
# DEEPTB INFO    Epoch 88 summary:	train_loss: 0.0077
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep88
# DEEPTB INFO    iteration:89	train_loss: 0.0077  (0.0078)	lr: 0.007677
# DEEPTB INFO    checkpoint saved as nnsk.iter89
# DEEPTB INFO    Epoch 89 summary:	train_loss: 0.0077
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep89
# DEEPTB INFO    iteration:90	train_loss: 0.0077  (0.0078)	lr: 0.007654
# DEEPTB INFO    checkpoint saved as nnsk.iter90
# DEEPTB INFO    Epoch 90 summary:	train_loss: 0.0077
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep90
# DEEPTB INFO    iteration:91	train_loss: 0.0076  (0.0077)	lr: 0.007631
# DEEPTB INFO    checkpoint saved as nnsk.iter91
# DEEPTB INFO    Epoch 91 summary:	train_loss: 0.0076
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep91
# DEEPTB INFO    iteration:92	train_loss: 0.0076  (0.0077)	lr: 0.007608
# DEEPTB INFO    checkpoint saved as nnsk.iter92
# DEEPTB INFO    Epoch 92 summary:	train_loss: 0.0076
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep92
# DEEPTB INFO    iteration:93	train_loss: 0.0075  (0.0076)	lr: 0.007585
# DEEPTB INFO    checkpoint saved as nnsk.iter93
# DEEPTB INFO    Epoch 93 summary:	train_loss: 0.0075
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep93
# DEEPTB INFO    iteration:94	train_loss: 0.0075  (0.0076)	lr: 0.007562
# DEEPTB INFO    checkpoint saved as nnsk.iter94
# DEEPTB INFO    Epoch 94 summary:	train_loss: 0.0075
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep94
# DEEPTB INFO    iteration:95	train_loss: 0.0075  (0.0076)	lr: 0.00754
# DEEPTB INFO    checkpoint saved as nnsk.iter95
# DEEPTB INFO    Epoch 95 summary:	train_loss: 0.0075
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep95
# DEEPTB INFO    iteration:96	train_loss: 0.0074  (0.0075)	lr: 0.007517
# DEEPTB INFO    checkpoint saved as nnsk.iter96
# DEEPTB INFO    Epoch 96 summary:	train_loss: 0.0074
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep96
# DEEPTB INFO    iteration:97	train_loss: 0.0074  (0.0075)	lr: 0.007494
# DEEPTB INFO    checkpoint saved as nnsk.iter97
# DEEPTB INFO    Epoch 97 summary:	train_loss: 0.0074
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep97
# DEEPTB INFO    iteration:98	train_loss: 0.0073  (0.0074)	lr: 0.007472
# DEEPTB INFO    checkpoint saved as nnsk.iter98
# DEEPTB INFO    Epoch 98 summary:	train_loss: 0.0073
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep98
# DEEPTB INFO    iteration:99	train_loss: 0.0073  (0.0074)	lr: 0.007449
# DEEPTB INFO    checkpoint saved as nnsk.iter99
# DEEPTB INFO    Epoch 99 summary:	train_loss: 0.0073
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep99
# DEEPTB INFO    iteration:100	train_loss: 0.0072  (0.0073)	lr: 0.007427
# DEEPTB INFO    checkpoint saved as nnsk.iter100
# DEEPTB INFO    Epoch 100 summary:	train_loss: 0.0072
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep100
# DEEPTB INFO    iteration:101	train_loss: 0.0072  (0.0073)	lr: 0.007405
# DEEPTB INFO    checkpoint saved as nnsk.iter101
# DEEPTB INFO    Epoch 101 summary:	train_loss: 0.0072
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep101
# DEEPTB INFO    iteration:102	train_loss: 0.0072  (0.0073)	lr: 0.007383
# DEEPTB INFO    checkpoint saved as nnsk.iter102
# DEEPTB INFO    Epoch 102 summary:	train_loss: 0.0072
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep102
# DEEPTB INFO    iteration:103	train_loss: 0.0071  (0.0072)	lr: 0.00736
# DEEPTB INFO    checkpoint saved as nnsk.iter103
# DEEPTB INFO    Epoch 103 summary:	train_loss: 0.0071
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep103
# DEEPTB INFO    iteration:104	train_loss: 0.0071  (0.0072)	lr: 0.007338
# DEEPTB INFO    checkpoint saved as nnsk.iter104
# DEEPTB INFO    Epoch 104 summary:	train_loss: 0.0071
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep104
# DEEPTB INFO    iteration:105	train_loss: 0.0071  (0.0072)	lr: 0.007316
# DEEPTB INFO    checkpoint saved as nnsk.iter105
# DEEPTB INFO    Epoch 105 summary:	train_loss: 0.0071
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep105
# DEEPTB INFO    iteration:106	train_loss: 0.0070  (0.0071)	lr: 0.007294
# DEEPTB INFO    checkpoint saved as nnsk.iter106
# DEEPTB INFO    Epoch 106 summary:	train_loss: 0.0070
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep106
# DEEPTB INFO    iteration:107	train_loss: 0.0070  (0.0071)	lr: 0.007273
# DEEPTB INFO    checkpoint saved as nnsk.iter107
# DEEPTB INFO    Epoch 107 summary:	train_loss: 0.0070
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep107
# DEEPTB INFO    iteration:108	train_loss: 0.0070  (0.0071)	lr: 0.007251
# DEEPTB INFO    checkpoint saved as nnsk.iter108
# DEEPTB INFO    Epoch 108 summary:	train_loss: 0.0070
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep108
# DEEPTB INFO    iteration:109	train_loss: 0.0070  (0.0070)	lr: 0.007229
# DEEPTB INFO    checkpoint saved as nnsk.iter109
# DEEPTB INFO    Epoch 109 summary:	train_loss: 0.0070
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep109
# DEEPTB INFO    iteration:110	train_loss: 0.0069  (0.0070)	lr: 0.007207
# DEEPTB INFO    checkpoint saved as nnsk.iter110
# DEEPTB INFO    Epoch 110 summary:	train_loss: 0.0069
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep110
# DEEPTB INFO    iteration:111	train_loss: 0.0069  (0.0070)	lr: 0.007186
# DEEPTB INFO    checkpoint saved as nnsk.iter111
# DEEPTB INFO    Epoch 111 summary:	train_loss: 0.0069
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep111
# DEEPTB INFO    iteration:112	train_loss: 0.0069  (0.0069)	lr: 0.007164
# DEEPTB INFO    checkpoint saved as nnsk.iter112
# DEEPTB INFO    Epoch 112 summary:	train_loss: 0.0069
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep112
# DEEPTB INFO    iteration:113	train_loss: 0.0069  (0.0069)	lr: 0.007143
# DEEPTB INFO    checkpoint saved as nnsk.iter113
# DEEPTB INFO    Epoch 113 summary:	train_loss: 0.0069
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep113
# DEEPTB INFO    iteration:114	train_loss: 0.0068  (0.0069)	lr: 0.007121
# DEEPTB INFO    checkpoint saved as nnsk.iter114
# DEEPTB INFO    Epoch 114 summary:	train_loss: 0.0068
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep114
# DEEPTB INFO    iteration:115	train_loss: 0.0068  (0.0069)	lr: 0.0071
# DEEPTB INFO    checkpoint saved as nnsk.iter115
# DEEPTB INFO    Epoch 115 summary:	train_loss: 0.0068
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep115
# DEEPTB INFO    iteration:116	train_loss: 0.0068  (0.0068)	lr: 0.007079
# DEEPTB INFO    checkpoint saved as nnsk.iter116
# DEEPTB INFO    Epoch 116 summary:	train_loss: 0.0068
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep116
# DEEPTB INFO    iteration:117	train_loss: 0.0068  (0.0068)	lr: 0.007057
# DEEPTB INFO    checkpoint saved as nnsk.iter117
# DEEPTB INFO    Epoch 117 summary:	train_loss: 0.0068
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep117
# DEEPTB INFO    iteration:118	train_loss: 0.0067  (0.0068)	lr: 0.007036
# DEEPTB INFO    checkpoint saved as nnsk.iter118
# DEEPTB INFO    Epoch 118 summary:	train_loss: 0.0067
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep118
# DEEPTB INFO    iteration:119	train_loss: 0.0067  (0.0068)	lr: 0.007015
# DEEPTB INFO    checkpoint saved as nnsk.iter119
# DEEPTB INFO    Epoch 119 summary:	train_loss: 0.0067
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep119
# DEEPTB INFO    iteration:120	train_loss: 0.0067  (0.0068)	lr: 0.006994
# DEEPTB INFO    checkpoint saved as nnsk.iter120
# DEEPTB INFO    Epoch 120 summary:	train_loss: 0.0067
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep120
# DEEPTB INFO    iteration:121	train_loss: 0.0067  (0.0067)	lr: 0.006973
# DEEPTB INFO    checkpoint saved as nnsk.iter121
# DEEPTB INFO    Epoch 121 summary:	train_loss: 0.0067
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep121
# DEEPTB INFO    iteration:122	train_loss: 0.0067  (0.0067)	lr: 0.006952
# DEEPTB INFO    checkpoint saved as nnsk.iter122
# DEEPTB INFO    Epoch 122 summary:	train_loss: 0.0067
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep122
# DEEPTB INFO    iteration:123	train_loss: 0.0066  (0.0067)	lr: 0.006931
# DEEPTB INFO    checkpoint saved as nnsk.iter123
# DEEPTB INFO    Epoch 123 summary:	train_loss: 0.0066
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep123
# DEEPTB INFO    iteration:124	train_loss: 0.0066  (0.0067)	lr: 0.00691
# DEEPTB INFO    checkpoint saved as nnsk.iter124
# DEEPTB INFO    Epoch 124 summary:	train_loss: 0.0066
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep124
# DEEPTB INFO    iteration:125	train_loss: 0.0066  (0.0067)	lr: 0.00689
# DEEPTB INFO    checkpoint saved as nnsk.iter125
# DEEPTB INFO    Epoch 125 summary:	train_loss: 0.0066
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep125
# DEEPTB INFO    iteration:126	train_loss: 0.0066  (0.0066)	lr: 0.006869
# DEEPTB INFO    checkpoint saved as nnsk.iter126
# DEEPTB INFO    Epoch 126 summary:	train_loss: 0.0066
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep126
# DEEPTB INFO    iteration:127	train_loss: 0.0066  (0.0066)	lr: 0.006848
# DEEPTB INFO    checkpoint saved as nnsk.iter127
# DEEPTB INFO    Epoch 127 summary:	train_loss: 0.0066
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep127
# DEEPTB INFO    iteration:128	train_loss: 0.0066  (0.0066)	lr: 0.006828
# DEEPTB INFO    checkpoint saved as nnsk.iter128
# DEEPTB INFO    Epoch 128 summary:	train_loss: 0.0066
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep128
# DEEPTB INFO    iteration:129	train_loss: 0.0066  (0.0066)	lr: 0.006807
# DEEPTB INFO    checkpoint saved as nnsk.iter129
# DEEPTB INFO    Epoch 129 summary:	train_loss: 0.0066
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep129
# DEEPTB INFO    iteration:130	train_loss: 0.0065  (0.0066)	lr: 0.006787
# DEEPTB INFO    checkpoint saved as nnsk.iter130
# DEEPTB INFO    Epoch 130 summary:	train_loss: 0.0065
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep130
# DEEPTB INFO    iteration:131	train_loss: 0.0065  (0.0066)	lr: 0.006767
# DEEPTB INFO    checkpoint saved as nnsk.iter131
# DEEPTB INFO    Epoch 131 summary:	train_loss: 0.0065
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep131
# DEEPTB INFO    iteration:132	train_loss: 0.0065  (0.0065)	lr: 0.006746
# DEEPTB INFO    checkpoint saved as nnsk.iter132
# DEEPTB INFO    Epoch 132 summary:	train_loss: 0.0065
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep132
# DEEPTB INFO    iteration:133	train_loss: 0.0065  (0.0065)	lr: 0.006726
# DEEPTB INFO    checkpoint saved as nnsk.iter133
# DEEPTB INFO    Epoch 133 summary:	train_loss: 0.0065
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep133
# DEEPTB INFO    iteration:134	train_loss: 0.0065  (0.0065)	lr: 0.006706
# DEEPTB INFO    checkpoint saved as nnsk.iter134
# DEEPTB INFO    Epoch 134 summary:	train_loss: 0.0065
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep134
# DEEPTB INFO    iteration:135	train_loss: 0.0065  (0.0065)	lr: 0.006686
# DEEPTB INFO    checkpoint saved as nnsk.iter135
# DEEPTB INFO    Epoch 135 summary:	train_loss: 0.0065
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep135
# DEEPTB INFO    iteration:136	train_loss: 0.0065  (0.0065)	lr: 0.006666
# DEEPTB INFO    checkpoint saved as nnsk.iter136
# DEEPTB INFO    Epoch 136 summary:	train_loss: 0.0065
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep136
# DEEPTB INFO    iteration:137	train_loss: 0.0064  (0.0065)	lr: 0.006646
# DEEPTB INFO    checkpoint saved as nnsk.iter137
# DEEPTB INFO    Epoch 137 summary:	train_loss: 0.0064
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep137
# DEEPTB INFO    iteration:138	train_loss: 0.0064  (0.0065)	lr: 0.006626
# DEEPTB INFO    checkpoint saved as nnsk.iter138
# DEEPTB INFO    Epoch 138 summary:	train_loss: 0.0064
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep138
# DEEPTB INFO    iteration:139	train_loss: 0.0064  (0.0065)	lr: 0.006606
# DEEPTB INFO    checkpoint saved as nnsk.iter139
# DEEPTB INFO    Epoch 139 summary:	train_loss: 0.0064
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep139
# DEEPTB INFO    iteration:140	train_loss: 0.0064  (0.0064)	lr: 0.006586
# DEEPTB INFO    checkpoint saved as nnsk.iter140
# DEEPTB INFO    Epoch 140 summary:	train_loss: 0.0064
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep140
# DEEPTB INFO    iteration:141	train_loss: 0.0064  (0.0064)	lr: 0.006566
# DEEPTB INFO    checkpoint saved as nnsk.iter141
# DEEPTB INFO    Epoch 141 summary:	train_loss: 0.0064
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep141
# DEEPTB INFO    iteration:142	train_loss: 0.0064  (0.0064)	lr: 0.006547
# DEEPTB INFO    checkpoint saved as nnsk.iter142
# DEEPTB INFO    Epoch 142 summary:	train_loss: 0.0064
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep142
# DEEPTB INFO    iteration:143	train_loss: 0.0064  (0.0064)	lr: 0.006527
# DEEPTB INFO    checkpoint saved as nnsk.iter143
# DEEPTB INFO    Epoch 143 summary:	train_loss: 0.0064
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep143
# DEEPTB INFO    iteration:144	train_loss: 0.0064  (0.0064)	lr: 0.006507
# DEEPTB INFO    checkpoint saved as nnsk.iter144
# DEEPTB INFO    Epoch 144 summary:	train_loss: 0.0064
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep144
# DEEPTB INFO    iteration:145	train_loss: 0.0064  (0.0064)	lr: 0.006488
# DEEPTB INFO    checkpoint saved as nnsk.iter145
# DEEPTB INFO    Epoch 145 summary:	train_loss: 0.0064
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep145
# DEEPTB INFO    iteration:146	train_loss: 0.0063  (0.0064)	lr: 0.006468
# DEEPTB INFO    checkpoint saved as nnsk.iter146
# DEEPTB INFO    Epoch 146 summary:	train_loss: 0.0063
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep146
# DEEPTB INFO    iteration:147	train_loss: 0.0063  (0.0064)	lr: 0.006449
# DEEPTB INFO    checkpoint saved as nnsk.iter147
# DEEPTB INFO    Epoch 147 summary:	train_loss: 0.0063
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep147
# DEEPTB INFO    iteration:148	train_loss: 0.0063  (0.0063)	lr: 0.00643
# DEEPTB INFO    checkpoint saved as nnsk.iter148
# DEEPTB INFO    Epoch 148 summary:	train_loss: 0.0063
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep148
# DEEPTB INFO    iteration:149	train_loss: 0.0063  (0.0063)	lr: 0.00641
# DEEPTB INFO    checkpoint saved as nnsk.iter149
# DEEPTB INFO    Epoch 149 summary:	train_loss: 0.0063
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep149
# DEEPTB INFO    iteration:150	train_loss: 0.0063  (0.0063)	lr: 0.006391
# DEEPTB INFO    checkpoint saved as nnsk.iter150
# DEEPTB INFO    Epoch 150 summary:	train_loss: 0.0063
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep150
# DEEPTB INFO    iteration:151	train_loss: 0.0063  (0.0063)	lr: 0.006372
# DEEPTB INFO    checkpoint saved as nnsk.iter151
# DEEPTB INFO    Epoch 151 summary:	train_loss: 0.0063
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep151
# DEEPTB INFO    iteration:152	train_loss: 0.0063  (0.0063)	lr: 0.006353
# DEEPTB INFO    checkpoint saved as nnsk.iter152
# DEEPTB INFO    Epoch 152 summary:	train_loss: 0.0063
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep152
# DEEPTB INFO    iteration:153	train_loss: 0.0063  (0.0063)	lr: 0.006334
# DEEPTB INFO    checkpoint saved as nnsk.iter153
# DEEPTB INFO    Epoch 153 summary:	train_loss: 0.0063
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep153
# DEEPTB INFO    iteration:154	train_loss: 0.0063  (0.0063)	lr: 0.006315
# DEEPTB INFO    checkpoint saved as nnsk.iter154
# DEEPTB INFO    Epoch 154 summary:	train_loss: 0.0063
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep154
# DEEPTB INFO    iteration:155	train_loss: 0.0063  (0.0063)	lr: 0.006296
# DEEPTB INFO    checkpoint saved as nnsk.iter155
# DEEPTB INFO    Epoch 155 summary:	train_loss: 0.0063
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep155
# DEEPTB INFO    iteration:156	train_loss: 0.0062  (0.0063)	lr: 0.006277
# DEEPTB INFO    checkpoint saved as nnsk.iter156
# DEEPTB INFO    Epoch 156 summary:	train_loss: 0.0062
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep156
# DEEPTB INFO    iteration:157	train_loss: 0.0062  (0.0063)	lr: 0.006258
# DEEPTB INFO    checkpoint saved as nnsk.iter157
# DEEPTB INFO    Epoch 157 summary:	train_loss: 0.0062
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep157
# DEEPTB INFO    iteration:158	train_loss: 0.0062  (0.0062)	lr: 0.006239
# DEEPTB INFO    checkpoint saved as nnsk.iter158
# DEEPTB INFO    Epoch 158 summary:	train_loss: 0.0062
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep158
# DEEPTB INFO    iteration:159	train_loss: 0.0062  (0.0062)	lr: 0.006221
# ...
# DEEPTB INFO    checkpoint saved as nnsk.iter448
# DEEPTB INFO    Epoch 448 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep448
# DEEPTB INFO    iteration:449	train_loss: 0.0035  (0.0036)	lr: 0.002603
# DEEPTB INFO    checkpoint saved as nnsk.iter449
# DEEPTB INFO    Epoch 449 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep449
# DEEPTB INFO    iteration:450	train_loss: 0.0035  (0.0035)	lr: 0.002595
# DEEPTB INFO    checkpoint saved as nnsk.iter450
# DEEPTB INFO    Epoch 450 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep450
# DEEPTB INFO    iteration:451	train_loss: 0.0035  (0.0035)	lr: 0.002587
# DEEPTB INFO    checkpoint saved as nnsk.iter451
# DEEPTB INFO    Epoch 451 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep451
# DEEPTB INFO    iteration:452	train_loss: 0.0035  (0.0035)	lr: 0.002579
# DEEPTB INFO    checkpoint saved as nnsk.iter452
# DEEPTB INFO    Epoch 452 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep452
# DEEPTB INFO    iteration:453	train_loss: 0.0035  (0.0035)	lr: 0.002572
# DEEPTB INFO    checkpoint saved as nnsk.iter453
# DEEPTB INFO    Epoch 453 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep453
# DEEPTB INFO    iteration:454	train_loss: 0.0035  (0.0035)	lr: 0.002564
# DEEPTB INFO    checkpoint saved as nnsk.iter454
# DEEPTB INFO    Epoch 454 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep454
# DEEPTB INFO    iteration:455	train_loss: 0.0035  (0.0035)	lr: 0.002556
# DEEPTB INFO    checkpoint saved as nnsk.iter455
# DEEPTB INFO    Epoch 455 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep455
# DEEPTB INFO    iteration:456	train_loss: 0.0035  (0.0035)	lr: 0.002549
# DEEPTB INFO    checkpoint saved as nnsk.iter456
# DEEPTB INFO    Epoch 456 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep456
# DEEPTB INFO    iteration:457	train_loss: 0.0035  (0.0035)	lr: 0.002541
# DEEPTB INFO    checkpoint saved as nnsk.iter457
# DEEPTB INFO    Epoch 457 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep457
# DEEPTB INFO    iteration:458	train_loss: 0.0035  (0.0035)	lr: 0.002533
# DEEPTB INFO    checkpoint saved as nnsk.iter458
# DEEPTB INFO    Epoch 458 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep458
# DEEPTB INFO    iteration:459	train_loss: 0.0035  (0.0035)	lr: 0.002526
# DEEPTB INFO    checkpoint saved as nnsk.iter459
# DEEPTB INFO    Epoch 459 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep459
# DEEPTB INFO    iteration:460	train_loss: 0.0035  (0.0035)	lr: 0.002518
# DEEPTB INFO    checkpoint saved as nnsk.iter460
# DEEPTB INFO    Epoch 460 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep460
# DEEPTB INFO    iteration:461	train_loss: 0.0035  (0.0035)	lr: 0.002511
# DEEPTB INFO    checkpoint saved as nnsk.iter461
# DEEPTB INFO    Epoch 461 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep461
# DEEPTB INFO    iteration:462	train_loss: 0.0035  (0.0035)	lr: 0.002503
# DEEPTB INFO    checkpoint saved as nnsk.iter462
# DEEPTB INFO    Epoch 462 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep462
# DEEPTB INFO    iteration:463	train_loss: 0.0035  (0.0035)	lr: 0.002496
# DEEPTB INFO    checkpoint saved as nnsk.iter463
# DEEPTB INFO    Epoch 463 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep463
# DEEPTB INFO    iteration:464	train_loss: 0.0035  (0.0035)	lr: 0.002488
# DEEPTB INFO    checkpoint saved as nnsk.iter464
# DEEPTB INFO    Epoch 464 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep464
# DEEPTB INFO    iteration:465	train_loss: 0.0035  (0.0035)	lr: 0.002481
# DEEPTB INFO    checkpoint saved as nnsk.iter465
# DEEPTB INFO    Epoch 465 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep465
# DEEPTB INFO    iteration:466	train_loss: 0.0035  (0.0035)	lr: 0.002473
# DEEPTB INFO    checkpoint saved as nnsk.iter466
# DEEPTB INFO    Epoch 466 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep466
# DEEPTB INFO    iteration:467	train_loss: 0.0035  (0.0035)	lr: 0.002466
# DEEPTB INFO    checkpoint saved as nnsk.iter467
# DEEPTB INFO    Epoch 467 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep467
# DEEPTB INFO    iteration:468	train_loss: 0.0035  (0.0035)	lr: 0.002458
# DEEPTB INFO    checkpoint saved as nnsk.iter468
# DEEPTB INFO    Epoch 468 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep468
# DEEPTB INFO    iteration:469	train_loss: 0.0035  (0.0035)	lr: 0.002451
# DEEPTB INFO    checkpoint saved as nnsk.iter469
# DEEPTB INFO    Epoch 469 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep469
# DEEPTB INFO    iteration:470	train_loss: 0.0035  (0.0035)	lr: 0.002444
# DEEPTB INFO    checkpoint saved as nnsk.iter470
# DEEPTB INFO    Epoch 470 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep470
# DEEPTB INFO    iteration:471	train_loss: 0.0035  (0.0035)	lr: 0.002436
# DEEPTB INFO    checkpoint saved as nnsk.iter471
# DEEPTB INFO    Epoch 471 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep471
# DEEPTB INFO    iteration:472	train_loss: 0.0035  (0.0035)	lr: 0.002429
# DEEPTB INFO    checkpoint saved as nnsk.iter472
# DEEPTB INFO    Epoch 472 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep472
# DEEPTB INFO    iteration:473	train_loss: 0.0035  (0.0035)	lr: 0.002422
# DEEPTB INFO    checkpoint saved as nnsk.iter473
# DEEPTB INFO    Epoch 473 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep473
# DEEPTB INFO    iteration:474	train_loss: 0.0035  (0.0035)	lr: 0.002414
# DEEPTB INFO    checkpoint saved as nnsk.iter474
# DEEPTB INFO    Epoch 474 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep474
# DEEPTB INFO    iteration:475	train_loss: 0.0035  (0.0035)	lr: 0.002407
# DEEPTB INFO    checkpoint saved as nnsk.iter475
# DEEPTB INFO    Epoch 475 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep475
# DEEPTB INFO    iteration:476	train_loss: 0.0035  (0.0035)	lr: 0.0024
# DEEPTB INFO    checkpoint saved as nnsk.iter476
# DEEPTB INFO    Epoch 476 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep476
# DEEPTB INFO    iteration:477	train_loss: 0.0035  (0.0035)	lr: 0.002393
# DEEPTB INFO    checkpoint saved as nnsk.iter477
# DEEPTB INFO    Epoch 477 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep477
# DEEPTB INFO    iteration:478	train_loss: 0.0035  (0.0035)	lr: 0.002386
# DEEPTB INFO    checkpoint saved as nnsk.iter478
# DEEPTB INFO    Epoch 478 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep478
# DEEPTB INFO    iteration:479	train_loss: 0.0035  (0.0035)	lr: 0.002378
# DEEPTB INFO    checkpoint saved as nnsk.iter479
# DEEPTB INFO    Epoch 479 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep479
# DEEPTB INFO    iteration:480	train_loss: 0.0035  (0.0035)	lr: 0.002371
# DEEPTB INFO    checkpoint saved as nnsk.iter480
# DEEPTB INFO    Epoch 480 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep480
# DEEPTB INFO    iteration:481	train_loss: 0.0035  (0.0035)	lr: 0.002364
# DEEPTB INFO    checkpoint saved as nnsk.iter481
# DEEPTB INFO    Epoch 481 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep481
# DEEPTB INFO    iteration:482	train_loss: 0.0035  (0.0035)	lr: 0.002357
# DEEPTB INFO    checkpoint saved as nnsk.iter482
# DEEPTB INFO    Epoch 482 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep482
# DEEPTB INFO    iteration:483	train_loss: 0.0035  (0.0035)	lr: 0.00235
# DEEPTB INFO    checkpoint saved as nnsk.iter483
# DEEPTB INFO    Epoch 483 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep483
# DEEPTB INFO    iteration:484	train_loss: 0.0035  (0.0035)	lr: 0.002343
# DEEPTB INFO    checkpoint saved as nnsk.iter484
# DEEPTB INFO    Epoch 484 summary:	train_loss: 0.0035
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep484
# DEEPTB INFO    iteration:485	train_loss: 0.0034  (0.0035)	lr: 0.002336
# DEEPTB INFO    checkpoint saved as nnsk.iter485
# DEEPTB INFO    Epoch 485 summary:	train_loss: 0.0034
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep485
# DEEPTB INFO    iteration:486	train_loss: 0.0034  (0.0035)	lr: 0.002329
# DEEPTB INFO    checkpoint saved as nnsk.iter486
# DEEPTB INFO    Epoch 486 summary:	train_loss: 0.0034
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep486
# DEEPTB INFO    iteration:487	train_loss: 0.0034  (0.0035)	lr: 0.002322
# DEEPTB INFO    checkpoint saved as nnsk.iter487
# DEEPTB INFO    Epoch 487 summary:	train_loss: 0.0034
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep487
# DEEPTB INFO    iteration:488	train_loss: 0.0034  (0.0034)	lr: 0.002315
# DEEPTB INFO    checkpoint saved as nnsk.iter488
# DEEPTB INFO    Epoch 488 summary:	train_loss: 0.0034
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep488
# DEEPTB INFO    iteration:489	train_loss: 0.0034  (0.0034)	lr: 0.002308
# DEEPTB INFO    checkpoint saved as nnsk.iter489
# DEEPTB INFO    Epoch 489 summary:	train_loss: 0.0034
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep489
# DEEPTB INFO    iteration:490	train_loss: 0.0034  (0.0034)	lr: 0.002301
# DEEPTB INFO    checkpoint saved as nnsk.iter490
# DEEPTB INFO    Epoch 490 summary:	train_loss: 0.0034
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep490
# DEEPTB INFO    iteration:491	train_loss: 0.0034  (0.0034)	lr: 0.002294
# DEEPTB INFO    checkpoint saved as nnsk.iter491
# DEEPTB INFO    Epoch 491 summary:	train_loss: 0.0034
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep491
# DEEPTB INFO    iteration:492	train_loss: 0.0034  (0.0034)	lr: 0.002287
# DEEPTB INFO    checkpoint saved as nnsk.iter492
# DEEPTB INFO    Epoch 492 summary:	train_loss: 0.0034
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep492
# DEEPTB INFO    iteration:493	train_loss: 0.0034  (0.0034)	lr: 0.00228
# DEEPTB INFO    checkpoint saved as nnsk.iter493
# DEEPTB INFO    Epoch 493 summary:	train_loss: 0.0034
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep493
# DEEPTB INFO    iteration:494	train_loss: 0.0034  (0.0034)	lr: 0.002274
# DEEPTB INFO    checkpoint saved as nnsk.iter494
# DEEPTB INFO    Epoch 494 summary:	train_loss: 0.0034
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep494
# DEEPTB INFO    iteration:495	train_loss: 0.0034  (0.0034)	lr: 0.002267
# DEEPTB INFO    checkpoint saved as nnsk.iter495
# DEEPTB INFO    Epoch 495 summary:	train_loss: 0.0034
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep495
# DEEPTB INFO    iteration:496	train_loss: 0.0034  (0.0034)	lr: 0.00226
# DEEPTB INFO    checkpoint saved as nnsk.iter496
# DEEPTB INFO    Epoch 496 summary:	train_loss: 0.0034
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep496
# DEEPTB INFO    iteration:497	train_loss: 0.0034  (0.0034)	lr: 0.002253
# DEEPTB INFO    checkpoint saved as nnsk.iter497
# DEEPTB INFO    Epoch 497 summary:	train_loss: 0.0034
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep497
# DEEPTB INFO    iteration:498	train_loss: 0.0034  (0.0034)	lr: 0.002246
# DEEPTB INFO    checkpoint saved as nnsk.iter498
# DEEPTB INFO    Epoch 498 summary:	train_loss: 0.0034
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep498
# DEEPTB INFO    iteration:499	train_loss: 0.0034  (0.0034)	lr: 0.00224
# DEEPTB INFO    checkpoint saved as nnsk.iter499
# DEEPTB INFO    Epoch 499 summary:	train_loss: 0.0034
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep499
# DEEPTB INFO    iteration:500	train_loss: 0.0034  (0.0034)	lr: 0.002233
# DEEPTB INFO    checkpoint saved as nnsk.iter500
# DEEPTB INFO    Epoch 500 summary:	train_loss: 0.0034
# ---------------------------------------------------------------------------------
# DEEPTB INFO    checkpoint saved as nnsk.ep500
# DEEPTB INFO    finished training
# DEEPTB INFO    wall time: 42.381 s

# %%
# !dptb run band.json -i ./nnsk2/checkpoint/nnsk.best.pth -o band_train
#!dptb run band.json -i ./ref_ckpt/nnsk_tr2.pth -o band_train


# display the band plot:
image_path = f'./band_train/results/band.png'
img = mpimg.imread(image_path)
plt.figure(figsize=(10, 8))
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# TBPLaS is not installed. Thus the TBPLaS is not available, Please install it first.
#
#
# #################################################################################
# #                                                                               #
# #                                                                               #
# #      ██████████                     ███████████  ███████████ ███████████      #
# #     ░░███░░░░███                   ░░███░░░░░███░█░░░███░░░█░░███░░░░░███     #
# #      ░███   ░░███  ██████   ██████  ░███    ░███░   ░███  ░  ░███    ░███     #
# #      ░███    ░███ ███░░███ ███░░███ ░██████████     ░███     ░██████████      #
# #      ░███    ░███░███████ ░███████  ░███░░░░░░      ░███     ░███░░░░░███     #
# #      ░███    ███ ░███░░░  ░███░░░   ░███            ░███     ░███    ░███     #
# #      ██████████  ░░██████ ░░██████  █████           █████    ███████████      #
# #     ░░░░░░░░░░    ░░░░░░   ░░░░░░  ░░░░░           ░░░░░    ░░░░░░░░░░░       #
# #                                                                               #
# #                         Version: 2.2.1.dev20+bcb3cf2                          #
# #                                                                               #
# #################################################################################
#
#
# DEEPTB INFO    The ['overlap_param'] are frozen!
# DEEPTB INFO    The ['overlap_param'] are frozen!
# DEEPTB WARNING Warning! structure is not set in run option, read from input config file.
# /Users/aisiqg/Software/venv/pydptb/lib/python3.9/site-packages/torch/nested/__init__.py:58: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/NestedTensorImpl.cpp:180.)
#   return torch._nested_tensor_from_tensor_list(tensor_list, dtype, None, device, None)
# DEEPTB INFO    KPOINTS  klist: 180 kpoints
# DEEPTB INFO    The eigenvalues are already in data. will use them.
# DEEPTB INFO    Calculating Fermi energy in the case of spin-degeneracy.
# DEEPTB WARNING Fermi level bisection did not converge under tolerance 1e-10 after 55 iterations.
# DEEPTB INFO    q_cal: 7.999999996401794, total_electrons: 8.0, diff q: 3.5982061774575413e-09
# DEEPTB INFO    Estimated E_fermi: -5.59063458442688 based on the valence electrons setting nel_atom : {'As': 5, 'Ga': 3} .
# DEEPTB INFO    No Fermi energy provided, using estimated value: -5.5906 eV
# Figure(640x560)
# DEEPTB INFO    band calculation successfully completed.

# %% [markdown]
# <div style="color:black; background-color:#FFF3E9; border: 1px solid #FFE0C3; border-radius: 10px; margin-bottom:1rem">
#     <p style="margin:1rem; padding-left: 1rem; line-height: 2.5;">
#         Author: <a style="font-weight:normal" href="mailto:guqq@ustc.edu.cn">Gu, Qiangqiang : guqq@ustc.edu.cn</a>
#     </p>
#     <p style="margin:1rem; padding-left: 1rem; line-height: 2.5;">
#         Thank you for reading!
#     </p>
#     <p style="margin:1rem; padding-left: 1rem; line-height: 2.5;">
#         For more information about training, please refer to tutorial 3.
#     </p>
#
#
# </div>
